# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %% [markdown]
# Observable trends:
# 1. The first trend to note is that the closer you are to the equator the higher the temperature is, as a general rule.
# 2. The coorelation between being closer to the equator and higher humidity is weak, but exists.
# 3. There is practically no correlation between latitude and wind speed. So, we can deduce that wind speed should not change much due to being closer or further from the equator.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from datetime import datetime
from scipy.stats import linregress
import scipy.stats as st

# Import API key
import config_from_pydata_env

weather_api_key = config_from_pydata_env.weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 618

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# url for openweather api
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"

# build query url
query_url = f"{url}appid={weather_api_key}&units={units}&q="

# %%
# empty lists to hold query information
lat = []
temp = []
temp_max = []
humidity = []
wind_speed = []
lon = []
date = []
country = []
cloudiness = []


# loop through list of cities and request information
count = 0
set = 1
for city in cities:
    count = count + 1
    # using sleep here to not reach api limit
    if count == 51:
        count = 1
        set = set + 1
        time.sleep(5)
    print(f"Processing Record {count} of Set {set} | {city}")
    try:
        response = requests.get(query_url + city).json()
        lat.append(response['coord']['lat'])
        lon.append(response['coord']['lon'])
        temp.append(response['main']['temp'])
        temp_max.append(response['main']['temp_max'])
        humidity.append(response['main']['humidity'])
        wind_speed.append(response['wind']['speed'])
        date.append(response['dt'])
        country.append(response['sys']['country'])
        cloudiness.append(response['clouds']['all'])
    except:
        print("City not found. Skipping...")
        lat.append(np.nan)
        lon.append(np.nan)
        temp.append(np.nan)
        temp_max.append(np.nan)
        humidity.append(np.nan)
        wind_speed.append(np.nan)
        date.append(np.nan)
        country.append(np.nan)
        cloudiness.append(np.nan)
    continue
print("Data Retrieval Complete")
# Out:
# Processing Record 1 of Set 1 | ushuaia
# Processing Record 2 of Set 1 | auki
# Processing Record 3 of Set 1 | kaitangata
# Processing Record 4 of Set 1 | tuktoyaktuk
# Processing Record 5 of Set 1 | punta arenas
# Processing Record 6 of Set 1 | port elizabeth
# Processing Record 7 of Set 1 | marsa matruh
# Processing Record 8 of Set 1 | raga
# Processing Record 9 of Set 1 | east london
# Processing Record 10 of Set 1 | salta
# Processing Record 11 of Set 1 | yellowknife
# Processing Record 12 of Set 1 | hun
# Processing Record 13 of Set 1 | ootmarsum
# Processing Record 14 of Set 1 | mehamn
# Processing Record 15 of Set 1 | puerto ayora
# Processing Record 16 of Set 1 | gao
# Processing Record 17 of Set 1 | kapaa
# Processing Record 18 of Set 1 | sorvag
# City not found. Skipping...
# Processing Record 19 of Set 1 | cape town
# Processing Record 20 of Set 1 | bluff
# Processing Record 21 of Set 1 | coari
# Processing Record 22 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 23 of Set 1 | san vicente
# Processing Record 24 of Set 1 | hayden
# Processing Record 25 of Set 1 | saint-pierre
# Processing Record 26 of Set 1 | adrar
# Processing Record 27 of Set 1 | nome
# Processing Record 28 of Set 1 | nikolskoye
# Processing Record 29 of Set 1 | port alfred
# Processing Record 30 of Set 1 | rikitea
# Processing Record 31 of Set 1 | bambous virieux
# Processing Record 32 of Set 1 | geraldton
# Processing Record 33 of Set 1 | hermanus
# Processing Record 34 of Set 1 | hobart
# Processing Record 35 of Set 1 | taoudenni
# Processing Record 36 of Set 1 | imuris
# Processing Record 37 of Set 1 | hilo
# Processing Record 38 of Set 1 | cayeli
# Processing Record 39 of Set 1 | mayaposi
# City not found. Skipping...
# Processing Record 40 of Set 1 | longyearbyen
# Processing Record 41 of Set 1 | bredasdorp
# Processing Record 42 of Set 1 | mataura
# Processing Record 43 of Set 1 | halalo
# City not found. Skipping...
# Processing Record 44 of Set 1 | artyk
# City not found. Skipping...
# Processing Record 45 of Set 1 | mahebourg
# Processing Record 46 of Set 1 | atuona
# Processing Record 47 of Set 1 | nizhnevartovsk
# Processing Record 48 of Set 1 | arraial do cabo
# Processing Record 49 of Set 1 | albany
# Processing Record 50 of Set 1 | mogadishu
# Processing Record 1 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 2 of Set 2 | esperance
# Processing Record 3 of Set 2 | kavali
# Processing Record 4 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 5 of Set 2 | kadaya
# Processing Record 6 of Set 2 | jamestown
# Processing Record 7 of Set 2 | hithadhoo
# Processing Record 8 of Set 2 | barrow
# Processing Record 9 of Set 2 | sitka
# Processing Record 10 of Set 2 | bordusani
# Processing Record 11 of Set 2 | qasigiannguit
# Processing Record 12 of Set 2 | warwick
# Processing Record 13 of Set 2 | dryden
# Processing Record 14 of Set 2 | port lincoln
# Processing Record 15 of Set 2 | vila velha
# Processing Record 16 of Set 2 | butaritari
# Processing Record 17 of Set 2 | peace river
# Processing Record 18 of Set 2 | chokurdakh
# Processing Record 19 of Set 2 | nemuro
# Processing Record 20 of Set 2 | nanortalik
# Processing Record 21 of Set 2 | chuy
# Processing Record 22 of Set 2 | kamaishi
# Processing Record 23 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 24 of Set 2 | sao jose da coroa grande
# Processing Record 25 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 26 of Set 2 | humberto de campos
# Processing Record 27 of Set 2 | upernavik
# Processing Record 28 of Set 2 | manokwari
# Processing Record 29 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 30 of Set 2 | houma
# Processing Record 31 of Set 2 | preobrazheniye
# Processing Record 32 of Set 2 | woodward
# Processing Record 33 of Set 2 | yambio
# Processing Record 34 of Set 2 | chau doc
# Processing Record 35 of Set 2 | santa fe
# Processing Record 36 of Set 2 | lodja
# Processing Record 37 of Set 2 | riachao das neves
# Processing Record 38 of Set 2 | busselton
# Processing Record 39 of Set 2 | hamilton
# Processing Record 40 of Set 2 | edd
# Processing Record 41 of Set 2 | senanga
# Processing Record 42 of Set 2 | san patricio
# Processing Record 43 of Set 2 | ilheus
# Processing Record 44 of Set 2 | kodiak
# Processing Record 45 of Set 2 | faya
# Processing Record 46 of Set 2 | mar del plata
# Processing Record 47 of Set 2 | mpulungu
# Processing Record 48 of Set 2 | broome
# Processing Record 49 of Set 2 | dikson
# Processing Record 50 of Set 2 | cervo
# Processing Record 1 of Set 3 | manta
# Processing Record 2 of Set 3 | lompoc
# Processing Record 3 of Set 3 | santa cruz cabralia
# Processing Record 4 of Set 3 | udon thani
# Processing Record 5 of Set 3 | kruisfontein
# Processing Record 6 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 7 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 8 of Set 3 | ahuimanu
# Processing Record 9 of Set 3 | anadyr
# Processing Record 10 of Set 3 | nouakchott
# Processing Record 11 of Set 3 | cururupu
# Processing Record 12 of Set 3 | saskylakh
# Processing Record 13 of Set 3 | port hedland
# Processing Record 14 of Set 3 | grand centre
# City not found. Skipping...
# Processing Record 15 of Set 3 | henties bay
# Processing Record 16 of Set 3 | ostrovnoy
# Processing Record 17 of Set 3 | nechi
# Processing Record 18 of Set 3 | lebu
# Processing Record 19 of Set 3 | anzio
# Processing Record 20 of Set 3 | kazalinsk
# City not found. Skipping...
# Processing Record 21 of Set 3 | bereda
# Processing Record 22 of Set 3 | kidal
# Processing Record 23 of Set 3 | axim
# Processing Record 24 of Set 3 | kharp
# Processing Record 25 of Set 3 | mildura
# Processing Record 26 of Set 3 | victoria
# Processing Record 27 of Set 3 | thompson
# Processing Record 28 of Set 3 | tura
# Processing Record 29 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 30 of Set 3 | codrington
# Processing Record 31 of Set 3 | pangnirtung
# Processing Record 32 of Set 3 | ponta do sol
# Processing Record 33 of Set 3 | cherskiy
# Processing Record 34 of Set 3 | sooke
# Processing Record 35 of Set 3 | qaanaaq
# Processing Record 36 of Set 3 | saldanha
# Processing Record 37 of Set 3 | avera
# Processing Record 38 of Set 3 | tilichiki
# Processing Record 39 of Set 3 | taltal
# Processing Record 40 of Set 3 | avarua
# Processing Record 41 of Set 3 | gravdal
# Processing Record 42 of Set 3 | tazovskiy
# Processing Record 43 of Set 3 | bathsheba
# Processing Record 44 of Set 3 | saint anthony
# Processing Record 45 of Set 3 | constitucion
# Processing Record 46 of Set 3 | carnarvon
# Processing Record 47 of Set 3 | port-gentil
# Processing Record 48 of Set 3 | hihifo
# City not found. Skipping...
# Processing Record 49 of Set 3 | airai
# Processing Record 50 of Set 3 | saint-philippe
# Processing Record 1 of Set 4 | ilulissat
# Processing Record 2 of Set 4 | morant bay
# Processing Record 3 of Set 4 | jieshi
# Processing Record 4 of Set 4 | huanan
# Processing Record 5 of Set 4 | motygino
# Processing Record 6 of Set 4 | okato
# Processing Record 7 of Set 4 | iranshahr
# Processing Record 8 of Set 4 | vaini
# Processing Record 9 of Set 4 | macaboboni
# City not found. Skipping...
# Processing Record 10 of Set 4 | khatanga
# Processing Record 11 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 12 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 13 of Set 4 | ijaki
# City not found. Skipping...
# Processing Record 14 of Set 4 | azangaro
# Processing Record 15 of Set 4 | cabo san lucas
# Processing Record 16 of Set 4 | kyren
# Processing Record 17 of Set 4 | safwah
# City not found. Skipping...
# Processing Record 18 of Set 4 | dhamtari
# Processing Record 19 of Set 4 | mana
# Processing Record 20 of Set 4 | lander
# Processing Record 21 of Set 4 | san luis
# Processing Record 22 of Set 4 | mezen
# Processing Record 23 of Set 4 | okitipupa
# Processing Record 24 of Set 4 | berga
# Processing Record 25 of Set 4 | los llanos de aridane
# Processing Record 26 of Set 4 | evensk
# Processing Record 27 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 28 of Set 4 | anjiang
# Processing Record 29 of Set 4 | yulara
# Processing Record 30 of Set 4 | aksarka
# Processing Record 31 of Set 4 | bria
# Processing Record 32 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 33 of Set 4 | young
# Processing Record 34 of Set 4 | fortuna
# Processing Record 35 of Set 4 | sarangani
# Processing Record 36 of Set 4 | pevek
# Processing Record 37 of Set 4 | kavieng
# Processing Record 38 of Set 4 | madang
# Processing Record 39 of Set 4 | dolores
# Processing Record 40 of Set 4 | paamiut
# Processing Record 41 of Set 4 | bonavista
# Processing Record 42 of Set 4 | urdzhar
# City not found. Skipping...
# Processing Record 43 of Set 4 | tasiilaq
# Processing Record 44 of Set 4 | tselinnoye
# Processing Record 45 of Set 4 | coquimbo
# Processing Record 46 of Set 4 | thira
# City not found. Skipping...
# Processing Record 47 of Set 4 | ondorhaan
# City not found. Skipping...
# Processing Record 48 of Set 4 | kondinskoye
# Processing Record 49 of Set 4 | antofagasta
# Processing Record 50 of Set 4 | ninh binh
# Processing Record 1 of Set 5 | grindavik
# Processing Record 2 of Set 5 | kuliyapitiya
# Processing Record 3 of Set 5 | winchester
# Processing Record 4 of Set 5 | governador valadares
# Processing Record 5 of Set 5 | new norfolk
# Processing Record 6 of Set 5 | torbay
# Processing Record 7 of Set 5 | kingaroy
# Processing Record 8 of Set 5 | vestmannaeyjar
# Processing Record 9 of Set 5 | barawe
# City not found. Skipping...
# Processing Record 10 of Set 5 | gisborne
# Processing Record 11 of Set 5 | maykain
# City not found. Skipping...
# Processing Record 12 of Set 5 | kindersley
# Processing Record 13 of Set 5 | vermilion
# Processing Record 14 of Set 5 | dolbeau
# City not found. Skipping...
# Processing Record 15 of Set 5 | aleksinac
# Processing Record 16 of Set 5 | saint george
# Processing Record 17 of Set 5 | morros
# Processing Record 18 of Set 5 | azimur
# City not found. Skipping...
# Processing Record 19 of Set 5 | lukovetskiy
# Processing Record 20 of Set 5 | vestmanna
# Processing Record 21 of Set 5 | bengkulu
# Processing Record 22 of Set 5 | kurchum
# Processing Record 23 of Set 5 | sakakah
# Processing Record 24 of Set 5 | qaqortoq
# Processing Record 25 of Set 5 | gusinoye ozero
# Processing Record 26 of Set 5 | salalah
# Processing Record 27 of Set 5 | tiksi
# Processing Record 28 of Set 5 | kamenka
# Processing Record 29 of Set 5 | rabo de peixe
# Processing Record 30 of Set 5 | hambantota
# Processing Record 31 of Set 5 | clyde river
# Processing Record 32 of Set 5 | dubbo
# Processing Record 33 of Set 5 | faanui
# Processing Record 34 of Set 5 | ahipara
# Processing Record 35 of Set 5 | bandarbeyla
# Processing Record 36 of Set 5 | anshun
# Processing Record 37 of Set 5 | mandalgovi
# Processing Record 38 of Set 5 | gurskoye
# City not found. Skipping...
# Processing Record 39 of Set 5 | moncton
# Processing Record 40 of Set 5 | sheridan
# Processing Record 41 of Set 5 | hofn
# Processing Record 42 of Set 5 | rocha
# Processing Record 43 of Set 5 | hasaki
# Processing Record 44 of Set 5 | baykit
# Processing Record 45 of Set 5 | kulhudhuffushi
# Processing Record 46 of Set 5 | baruun-urt
# Processing Record 47 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 48 of Set 5 | buraydah
# Processing Record 49 of Set 5 | zheleznodorozhnyy
# Processing Record 50 of Set 5 | fallon
# Processing Record 1 of Set 6 | shingu
# Processing Record 2 of Set 6 | zapolyarnyy
# Processing Record 3 of Set 6 | zhanatas
# City not found. Skipping...
# Processing Record 4 of Set 6 | aljezur
# Processing Record 5 of Set 6 | ceres
# Processing Record 6 of Set 6 | guerrero negro
# Processing Record 7 of Set 6 | mahajanga
# Processing Record 8 of Set 6 | okhotsk
# Processing Record 9 of Set 6 | huainan
# Processing Record 10 of Set 6 | zhangjiakou
# Processing Record 11 of Set 6 | inongo
# Processing Record 12 of Set 6 | kamenskoye
# City not found. Skipping...
# Processing Record 13 of Set 6 | serenje
# Processing Record 14 of Set 6 | wahran
# City not found. Skipping...
# Processing Record 15 of Set 6 | belmonte
# Processing Record 16 of Set 6 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 17 of Set 6 | saint-francois
# Processing Record 18 of Set 6 | karatuzskoye
# Processing Record 19 of Set 6 | palmer
# Processing Record 20 of Set 6 | itarema
# Processing Record 21 of Set 6 | ningbo
# Processing Record 22 of Set 6 | toliary
# City not found. Skipping...
# Processing Record 23 of Set 6 | yenagoa
# Processing Record 24 of Set 6 | stromness
# Processing Record 25 of Set 6 | hailar
# Processing Record 26 of Set 6 | saint-augustin
# Processing Record 27 of Set 6 | cidreira
# Processing Record 28 of Set 6 | georgetown
# Processing Record 29 of Set 6 | bamnet narong
# Processing Record 30 of Set 6 | gotsu
# Processing Record 31 of Set 6 | vasudevanallur
# Processing Record 32 of Set 6 | nouadhibou
# Processing Record 33 of Set 6 | sao filipe
# Processing Record 34 of Set 6 | wolfhagen
# Processing Record 35 of Set 6 | sinnamary
# Processing Record 36 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 37 of Set 6 | narsaq
# Processing Record 38 of Set 6 | bethel
# Processing Record 39 of Set 6 | kavaratti
# Processing Record 40 of Set 6 | salinas
# Processing Record 41 of Set 6 | ust-maya
# Processing Record 42 of Set 6 | chara
# Processing Record 43 of Set 6 | doha
# Processing Record 44 of Set 6 | massakory
# Processing Record 45 of Set 6 | muroto
# Processing Record 46 of Set 6 | pyaozerskiy
# Processing Record 47 of Set 6 | slave lake
# Processing Record 48 of Set 6 | cocobeach
# Processing Record 49 of Set 6 | conde
# Processing Record 50 of Set 6 | ylojarvi
# Processing Record 1 of Set 7 | marabba
# Processing Record 2 of Set 7 | erzin
# Processing Record 3 of Set 7 | paso de carrasco
# Processing Record 4 of Set 7 | egvekinot
# Processing Record 5 of Set 7 | jiexiu
# Processing Record 6 of Set 7 | asosa
# Processing Record 7 of Set 7 | araouane
# Processing Record 8 of Set 7 | luban
# Processing Record 9 of Set 7 | asfi
# Processing Record 10 of Set 7 | caranavi
# Processing Record 11 of Set 7 | castro
# Processing Record 12 of Set 7 | severo-kurilsk
# Processing Record 13 of Set 7 | fairbanks
# Processing Record 14 of Set 7 | ribeira grande
# Processing Record 15 of Set 7 | aflu
# City not found. Skipping...
# Processing Record 16 of Set 7 | bartlesville
# Processing Record 17 of Set 7 | usinsk
# Processing Record 18 of Set 7 | port hardy
# Processing Record 19 of Set 7 | meulaboh
# Processing Record 20 of Set 7 | tarko-sale
# Processing Record 21 of Set 7 | show low
# Processing Record 22 of Set 7 | shasta lake
# Processing Record 23 of Set 7 | dubti
# Processing Record 24 of Set 7 | buariki
# City not found. Skipping...
# Processing Record 25 of Set 7 | grand-santi
# Processing Record 26 of Set 7 | beaupre
# Processing Record 27 of Set 7 | lolua
# City not found. Skipping...
# Processing Record 28 of Set 7 | boddam
# Processing Record 29 of Set 7 | ancud
# Processing Record 30 of Set 7 | souillac
# Processing Record 31 of Set 7 | nisia floresta
# Processing Record 32 of Set 7 | robstown
# Processing Record 33 of Set 7 | zhigansk
# Processing Record 34 of Set 7 | bubaque
# Processing Record 35 of Set 7 | springfield
# Processing Record 36 of Set 7 | san cristobal
# Processing Record 37 of Set 7 | bluefields
# Processing Record 38 of Set 7 | khor
# Processing Record 39 of Set 7 | tuatapere
# Processing Record 40 of Set 7 | karauzyak
# City not found. Skipping...
# Processing Record 41 of Set 7 | ponta delgada
# Processing Record 42 of Set 7 | dvinskoy
# Processing Record 43 of Set 7 | kang
# Processing Record 44 of Set 7 | bagua grande
# Processing Record 45 of Set 7 | ziro
# Processing Record 46 of Set 7 | qujing
# Processing Record 47 of Set 7 | mpanda
# Processing Record 48 of Set 7 | batemans bay
# Processing Record 49 of Set 7 | cayhagan
# Processing Record 50 of Set 7 | fayaoue
# Processing Record 1 of Set 8 | lata
# Processing Record 2 of Set 8 | buala
# Processing Record 3 of Set 8 | muriti
# Processing Record 4 of Set 8 | lasa
# Processing Record 5 of Set 8 | yar-sale
# Processing Record 6 of Set 8 | loa janan
# Processing Record 7 of Set 8 | cheuskiny
# City not found. Skipping...
# Processing Record 8 of Set 8 | makakilo city
# Processing Record 9 of Set 8 | porto novo
# Processing Record 10 of Set 8 | kerrville
# Processing Record 11 of Set 8 | sebinkarahisar
# Processing Record 12 of Set 8 | safita
# Processing Record 13 of Set 8 | hami
# Processing Record 14 of Set 8 | luderitz
# Processing Record 15 of Set 8 | tommot
# Processing Record 16 of Set 8 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 17 of Set 8 | sorong
# Processing Record 18 of Set 8 | payakumbuh
# Processing Record 19 of Set 8 | bull savanna
# Processing Record 20 of Set 8 | lumby
# Processing Record 21 of Set 8 | husavik
# Processing Record 22 of Set 8 | lucapa
# Processing Record 23 of Set 8 | bima
# Processing Record 24 of Set 8 | nalut
# Processing Record 25 of Set 8 | cedar city
# Processing Record 26 of Set 8 | krasnyy yar
# Processing Record 27 of Set 8 | beringovskiy
# Processing Record 28 of Set 8 | saryshagan
# City not found. Skipping...
# Processing Record 29 of Set 8 | rincon
# Processing Record 30 of Set 8 | leningradskiy
# Processing Record 31 of Set 8 | poum
# Processing Record 32 of Set 8 | takoradi
# Processing Record 33 of Set 8 | palauig
# Processing Record 34 of Set 8 | roald
# Processing Record 35 of Set 8 | vilyuysk
# Processing Record 36 of Set 8 | orange cove
# Processing Record 37 of Set 8 | lagoa
# Processing Record 38 of Set 8 | muros
# Processing Record 39 of Set 8 | jasper
# Processing Record 40 of Set 8 | portmore
# Processing Record 41 of Set 8 | sayansk
# Processing Record 42 of Set 8 | ho
# City not found. Skipping...
# Processing Record 43 of Set 8 | camacha
# Processing Record 44 of Set 8 | dzhebariki-khaya
# Processing Record 45 of Set 8 | harper
# Processing Record 46 of Set 8 | hay river
# Processing Record 47 of Set 8 | port macquarie
# Processing Record 48 of Set 8 | cockburn town
# Processing Record 49 of Set 8 | batagay-alyta
# Processing Record 50 of Set 8 | pilar
# Processing Record 1 of Set 9 | onguday
# Processing Record 2 of Set 9 | dunedin
# Processing Record 3 of Set 9 | haguenau
# Processing Record 4 of Set 9 | alasehir
# Processing Record 5 of Set 9 | ciudad bolivar
# Processing Record 6 of Set 9 | litoral del san juan
# City not found. Skipping...
# Processing Record 7 of Set 9 | bend
# Processing Record 8 of Set 9 | grand gaube
# Processing Record 9 of Set 9 | kieta
# Processing Record 10 of Set 9 | pisco
# Processing Record 11 of Set 9 | kirakira
# Processing Record 12 of Set 9 | puerto madryn
# Processing Record 13 of Set 9 | bourail
# Processing Record 14 of Set 9 | padang
# Processing Record 15 of Set 9 | shimoda
# Processing Record 16 of Set 9 | galle
# Processing Record 17 of Set 9 | north bend
# Processing Record 18 of Set 9 | golden
# Processing Record 19 of Set 9 | vila franca do campo
# Processing Record 20 of Set 9 | temaraia
# City not found. Skipping...
# Processing Record 21 of Set 9 | valparaiso
# Processing Record 22 of Set 9 | benghazi
# Processing Record 23 of Set 9 | san pedro
# Processing Record 24 of Set 9 | arlit
# Processing Record 25 of Set 9 | casper
# Processing Record 26 of Set 9 | jiuquan
# Processing Record 27 of Set 9 | kihei
# Processing Record 28 of Set 9 | balkhash
# Processing Record 29 of Set 9 | tabiauea
# City not found. Skipping...
# Processing Record 30 of Set 9 | la paz
# Processing Record 31 of Set 9 | vallenar
# Processing Record 32 of Set 9 | kudahuvadhoo
# Processing Record 33 of Set 9 | yeniseysk
# Processing Record 34 of Set 9 | alto longa
# Processing Record 35 of Set 9 | maceio
# Processing Record 36 of Set 9 | talnakh
# Processing Record 37 of Set 9 | touros
# Processing Record 38 of Set 9 | rorvik
# Processing Record 39 of Set 9 | ganganagar
# Processing Record 40 of Set 9 | ixtapa
# Processing Record 41 of Set 9 | comodoro rivadavia
# Processing Record 42 of Set 9 | koslan
# Processing Record 43 of Set 9 | hobyo
# Processing Record 44 of Set 9 | yurginskoye
# Processing Record 45 of Set 9 | bambanglipuro
# Processing Record 46 of Set 9 | flinders
# Processing Record 47 of Set 9 | marcona
# City not found. Skipping...
# Processing Record 48 of Set 9 | utiroa
# City not found. Skipping...
# Processing Record 49 of Set 9 | tabou
# Processing Record 50 of Set 9 | pangkalanbuun
# Processing Record 1 of Set 10 | maridi
# Processing Record 2 of Set 10 | panaba
# Processing Record 3 of Set 10 | peniche
# Processing Record 4 of Set 10 | amos
# Processing Record 5 of Set 10 | beni
# Processing Record 6 of Set 10 | limbang
# Processing Record 7 of Set 10 | basco
# Processing Record 8 of Set 10 | santa cruz
# Processing Record 9 of Set 10 | vanimo
# Processing Record 10 of Set 10 | eureka
# Processing Record 11 of Set 10 | umzimvubu
# City not found. Skipping...
# Processing Record 12 of Set 10 | katsuura
# Processing Record 13 of Set 10 | beloha
# Processing Record 14 of Set 10 | novyy urengoy
# Processing Record 15 of Set 10 | qinhuangdao
# Processing Record 16 of Set 10 | samandag
# Processing Record 17 of Set 10 | dipkarpaz
# City not found. Skipping...
# Processing Record 18 of Set 10 | balkanabat
# Processing Record 19 of Set 10 | loreto
# Processing Record 20 of Set 10 | laguna
# Processing Record 21 of Set 10 | tazmalt
# Processing Record 22 of Set 10 | vyazma
# Processing Record 23 of Set 10 | provideniya
# Processing Record 24 of Set 10 | matara
# Processing Record 25 of Set 10 | asau
# Processing Record 26 of Set 10 | victor harbor
# Processing Record 27 of Set 10 | fare
# Processing Record 28 of Set 10 | charala
# Processing Record 29 of Set 10 | lavrentiya
# Processing Record 30 of Set 10 | buchanan
# Processing Record 31 of Set 10 | san quintin
# Processing Record 32 of Set 10 | kamennomostskiy
# Processing Record 33 of Set 10 | shache
# Processing Record 34 of Set 10 | tarnogskiy gorodok
# Processing Record 35 of Set 10 | olafsvik
# Processing Record 36 of Set 10 | keffi
# Processing Record 37 of Set 10 | vardo
# Processing Record 38 of Set 10 | tatvan
# Processing Record 39 of Set 10 | farah
# Processing Record 40 of Set 10 | moose factory
# Processing Record 41 of Set 10 | lorengau
# Processing Record 42 of Set 10 | bogoslovka
# Processing Record 43 of Set 10 | norman wells
# Processing Record 44 of Set 10 | eyl
# Processing Record 45 of Set 10 | astrea
# Processing Record 46 of Set 10 | guiuan
# Processing Record 47 of Set 10 | coahuayana
# Processing Record 48 of Set 10 | agadir
# Processing Record 49 of Set 10 | painesville
# Processing Record 50 of Set 10 | shirokiy
# Processing Record 1 of Set 11 | richards bay
# Processing Record 2 of Set 11 | atar
# Processing Record 3 of Set 11 | walvis bay
# Processing Record 4 of Set 11 | rio gallegos
# Processing Record 5 of Set 11 | inirida
# Processing Record 6 of Set 11 | krasnoufimsk
# Processing Record 7 of Set 11 | morondava
# Processing Record 8 of Set 11 | kifri
# Processing Record 9 of Set 11 | bitaogan
# Processing Record 10 of Set 11 | lamu
# Processing Record 11 of Set 11 | smithers
# Processing Record 12 of Set 11 | merauke
# Processing Record 13 of Set 11 | nabire
# Processing Record 14 of Set 11 | bababe
# City not found. Skipping...
# Processing Record 15 of Set 11 | iquitos
# Processing Record 16 of Set 11 | phalaborwa
# Processing Record 17 of Set 11 | la ronge
# Processing Record 18 of Set 11 | malanje
# Processing Record 19 of Set 11 | sangar
# Processing Record 20 of Set 11 | namtsy
# Processing Record 21 of Set 11 | haibowan
# City not found. Skipping...
# Processing Record 22 of Set 11 | bozhou
# Processing Record 23 of Set 11 | taldan
# Processing Record 24 of Set 11 | anchorage
# Processing Record 25 of Set 11 | cacapava do sul
# Processing Record 26 of Set 11 | mikuni
# Processing Record 27 of Set 11 | chowchilla
# Processing Record 28 of Set 11 | baracoa
# Processing Record 29 of Set 11 | monte patria
# Processing Record 30 of Set 11 | barsovo
# Processing Record 31 of Set 11 | shenjiamen
# Processing Record 32 of Set 11 | cayenne
# Processing Record 33 of Set 11 | mabaruma
# Processing Record 34 of Set 11 | bontang
# Processing Record 35 of Set 11 | chala
# Processing Record 36 of Set 11 | one hundred mile house
# City not found. Skipping...
# Processing Record 37 of Set 11 | tambura
# Processing Record 38 of Set 11 | alberton
# Processing Record 39 of Set 11 | iracoubo
# Processing Record 40 of Set 11 | yamandu
# Processing Record 41 of Set 11 | sao joao da barra
# Processing Record 42 of Set 11 | rovaniemi
# Processing Record 43 of Set 11 | moron
# Processing Record 44 of Set 11 | northam
# Processing Record 45 of Set 11 | svetlaya
# Processing Record 46 of Set 11 | llandrindod wells
# Processing Record 47 of Set 11 | topola
# Processing Record 48 of Set 11 | karratha
# Processing Record 49 of Set 11 | okhtyrka
# Processing Record 50 of Set 11 | iqaluit
# Processing Record 1 of Set 12 | schweinfurt
# Processing Record 2 of Set 12 | rawson
# Processing Record 3 of Set 12 | caravelas
# Processing Record 4 of Set 12 | dakoro
# Processing Record 5 of Set 12 | durres
# Processing Record 6 of Set 12 | batticaloa
# Processing Record 7 of Set 12 | shelburne
# Processing Record 8 of Set 12 | altamira
# Processing Record 9 of Set 12 | jumla
# Processing Record 10 of Set 12 | maniitsoq
# Processing Record 11 of Set 12 | duz
# City not found. Skipping...
# Processing Record 12 of Set 12 | samarai
# Processing Record 13 of Set 12 | najran
# Processing Record 14 of Set 12 | bur gabo
# City not found. Skipping...
# Processing Record 15 of Set 12 | adre
# Processing Record 16 of Set 12 | dingle
# Processing Record 17 of Set 12 | roebourne
# Processing Record 18 of Set 12 | namwala
# Processing Record 19 of Set 12 | alice springs
# Processing Record 20 of Set 12 | pontes e lacerda
# Processing Record 21 of Set 12 | tessalit
# Processing Record 22 of Set 12 | vanavara
# Processing Record 23 of Set 12 | oum hadjer
# Processing Record 24 of Set 12 | huarmey
# Processing Record 25 of Set 12 | timaru
# Processing Record 26 of Set 12 | sur
# Processing Record 27 of Set 12 | boende
# Processing Record 28 of Set 12 | micheweni
# Processing Record 29 of Set 12 | nizwa
# Processing Record 30 of Set 12 | sumbe
# Processing Record 31 of Set 12 | guarapari
# Processing Record 32 of Set 12 | kulaman
# Processing Record 33 of Set 12 | kungurtug
# Processing Record 34 of Set 12 | ayagoz
# Processing Record 35 of Set 12 | awjilah
# Processing Record 36 of Set 12 | dullewala
# Processing Record 37 of Set 12 | ginir
# Processing Record 38 of Set 12 | charcas
# Processing Record 39 of Set 12 | pinsk
# Processing Record 40 of Set 12 | maun
# Processing Record 41 of Set 12 | vostok
# Processing Record 42 of Set 12 | lafia
# Processing Record 43 of Set 12 | inyonga
# Processing Record 44 of Set 12 | manaus
# Processing Record 45 of Set 12 | mitsamiouli
# Processing Record 46 of Set 12 | tambopata
# Processing Record 47 of Set 12 | quetta
# Processing Record 48 of Set 12 | udachnyy
# Processing Record 49 of Set 12 | san carlos del zulia
# Processing Record 50 of Set 12 | mantsala
# Processing Record 1 of Set 13 | port-cartier
# Processing Record 2 of Set 13 | shitkino
# Processing Record 3 of Set 13 | aklavik
# Processing Record 4 of Set 13 | bratsk
# Processing Record 5 of Set 13 | kailua
# Processing Record 6 of Set 13 | mafeteng
# Processing Record 7 of Set 13 | petropavlovsk-kamchatskiy
# Processing Record 8 of Set 13 | broken hill
# Processing Record 9 of Set 13 | klaksvik
# Processing Record 10 of Set 13 | labutta
# City not found. Skipping...
# Processing Record 11 of Set 13 | hualmay
# Processing Record 12 of Set 13 | gainesville
# Processing Record 13 of Set 13 | czluchow
# Processing Record 14 of Set 13 | zubova polyana
# Processing Record 15 of Set 13 | neyshabur
# Processing Record 16 of Set 13 | teya
# Processing Record 17 of Set 13 | pitkyaranta
# Processing Record 18 of Set 13 | tehri
# Data Retrieval Complete

# %%
len(lat)
# Out:
# 618

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# convert raw data to dataframe
city_weather_df = pd.DataFrame({
    "City": cities,
    "Lat": lat,
    "Lng": lon,
    "Max Temp": temp_max,
    "Humidity": humidity,
    "Cloudiness": cloudiness,
    "Wind Speed": wind_speed,
    "Country": country,
    "Date": date,
})

# drop cities that were skipped because they could not be found by the api
city_weather_df = city_weather_df.dropna(how="any")

# %%
# export the city data into a .csv file within a folder named output_data
city_weather_df.to_csv("./output_data/city_weather_data.csv", index=False)

# display the dataframe
city_weather_df
# Out:
#                City    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0           ushuaia -54.80  -68.30     44.60      56.0        40.0
# 1              auki  -8.77  160.70     77.81      83.0       100.0
# 2        kaitangata -46.28  169.85     50.00      83.0       100.0
# 3       tuktoyaktuk  69.45 -133.04     23.00      85.0        90.0
# 4      punta arenas -53.15  -70.92     48.20      45.0        75.0
# ..              ...    ...     ...       ...       ...         ...
# 613  zubova polyana  54.08   42.84     37.53      89.0        90.0
# 614       neyshabur  36.21   58.80     54.16      29.0         0.0
# 615            teya  60.38   92.63     28.53      97.0        96.0
# 616     pitkyaranta  61.57   31.48     33.39      90.0         8.0
# 617           tehri  30.38   78.48     63.82      53.0         0.0
#
#      Wind Speed Country          Date
# 0         19.46      AR  1.603221e+09
# 1          5.55      SB  1.603222e+09
# 2          1.99      NZ  1.603221e+09
# 3         16.11      CA  1.603221e+09
# 4         14.99      CL  1.603221e+09
# ..          ...     ...           ...
# 613       11.43      RU  1.603222e+09
# 614        2.21      IR  1.603222e+09
# 615        2.84      RU  1.603221e+09
# 616        7.96      RU  1.603222e+09
# 617        3.69      IN  1.603222e+09
#
# [559 rows x 9 columns]

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#  Get the indices of cities that have humidity over 100%.

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
# set date time variable for title
date_time = datetime.date(datetime.now())

# create latitude vs temperature scatter plot
plt.scatter(city_weather_df["Lat"], city_weather_df["Max Temp"], facecolor = "c", edgecolor = "k")

# set title
plt.title(f"City Latitude vs Max Temperature{date_time}")

# set x axis label
plt.xlabel("Latitude")

# set y axis label
plt.ylabel("Max Temperature (F)")

# set grid line
plt.grid(linestyle='-', linewidth=1, alpha = 0.5)

# save the plotted figure as a png file in output data folder
plt.savefig("./output_data/city_latitude_temperature.png")

# show the scatterplot
plt.show()

# %% [markdown]
# The above scatterplot shows the relationship between latitude and max temperature of all the data gathered using OpenWeatherMaps API.

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
# create latitude vs humidity scatter plot
plt.scatter(city_weather_df["Lat"], city_weather_df["Humidity"], facecolor = "c", edgecolor = "k")

# set title
plt.title(f"City Latitude vs Humidity{date_time}")

# set x axis label
plt.xlabel("Latitude")

# set y axis label
plt.ylabel('Humidity (%)')

# set grid line
plt.grid(linestyle='-', linewidth=1, alpha = 0.5)

# save the plotted figure as a png file in output data folder
plt.savefig("./output_data/city_latitude_humidity.png")

# show the scatterplot
plt.show()

# %% [markdown]
# The above scatterplot shows the relationship between latitude and humidity of all the data gathered using OpenWeatherMaps API.

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
# create latitude vs cloudiness scatter plot
plt.scatter(city_weather_df["Lat"], city_weather_df["Cloudiness"], facecolor = "c", edgecolor = "k")

# set title
plt.title(f"City Latitude vs Cloudiness{date_time}")

# set x axis label
plt.xlabel("Latitude")

# set y axis label
plt.ylabel('Cloudiness(%)')

# set grid line
plt.grid(linestyle='-', linewidth=1, alpha = 0.5)

# save the plotted figure as a png file in output data folder
plt.savefig("./output_data/city_latitude_cloudiness.png")

# show the scatterplot
plt.show()

# %% [markdown]
# The above scatterplot shows the relationship between latitude and cloudiness of all the data gathered using OpenWeatherMaps API.

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
# create latitude vs wind speed scatter plot
plt.scatter(city_weather_df["Lat"], city_weather_df["Wind Speed"], facecolor = "c", edgecolor = "k")

# set title
plt.title(f"City Latitude vs Wind Speed{date_time}")

# set x axis label
plt.xlabel("Latitude")

# set y axis label
plt.ylabel('Wind Speed(mph)')

# set grid line
plt.grid(linestyle='-', linewidth=1, alpha = 0.5)

# save the plotted figure as a png file in output data folder
plt.savefig("./output_data/city_latitude_wind_speed.png")

# show the scatterplot
plt.show()

# %% [markdown]
# The above scatterplot shows the relationship between latitude and wind speed of all the data gathered using OpenWeatherMaps API.

# %% [markdown]
# ## Linear Regression

# %%
# northern and southern hemisphere dataframes
northern_hemisphere = city_weather_df.loc[city_weather_df["Lat"] >= 0]
southern_hemisphere = city_weather_df.loc[city_weather_df["Lat"] < 0]

# define linear regression and scatterplot function
def linear_regression(x,y):
    print(f"The r-squared is : {round(st.pearsonr(x, y)[0],2)}")
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
    regress_values = x * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    plt.scatter(x, y)
    plt.plot(x,regress_values,"r-")
    return line_eq

# function for annotation
def annotate(line_eq, a, b):
    plt.annotate(line_eq,(a,b),fontsize=15,color="red")

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# use linear regression function for northern hempisphere analysis
equation = linear_regression(northern_hemisphere["Lat"], northern_hemisphere["Max Temp"])

# annotate
annotate(equation, 0, 0)

# title for plot
plt.title("Northern Hemisphere - Max Temp vs. Latitude Linear Regression")

# set xlabel
plt.xlabel("Latitude")

# set ylabel
plt.ylabel("Max Temp (F)")

# save the plotted figure as a png file in output data folder
plt.savefig("./output_data/northern_temp_lat_regression.png")

# show the plot
plt.show()
# Out:
# The r-squared is : -0.88

# %% [markdown]
# In the above scatterplot we can see the linear regression displays a strong negative coorelation between max temperature and latitude when in the Northern Hemisphere. You can see that as the latitude increases away from the equator(0 degrees latitude), the temperature decreases. So, here is our evidence that it is hotter the closer you are to the equator as a general rule.

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# use linear regression function for southern hempisphere analysis
equation = linear_regression(southern_hemisphere["Lat"], southern_hemisphere["Max Temp"])

# annotate
annotate(equation, 0, 0)

# title for plot
plt.title("Southern Hemisphere - Max Temp vs. Latitude Linear Regression")

# set xlabel
plt.xlabel("Latitude")

# set ylabel
plt.ylabel("Max Temp(F)")

# save the plotted figure as a png file in output data folder
plt.savefig("./output_data/southern_temp_lat_regression.png")

# show the plot
plt.show()
# Out:
# The r-squared is : 0.78

# %% [markdown]
# In the above scatterplot we can see the linear regression displays a strong positive coorelation between max temperature and latitude when in the Southern Hemisphere. You can see that as the latitude increases towards the equator(0 degrees latitude), the temperature also increases. So, here is our evidence that it is hotter the closer you are to the equator as a general rule.

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# use linear regression function for northern hemisphere analysis
equation = linear_regression(northern_hemisphere["Lat"], northern_hemisphere["Humidity"])

# annotate
annotate(equation, 0, 0)

# title for plot
plt.title("Northern Hemisphere - Humidity vs. Latitude Linear Regression")

# set xlabel
plt.xlabel("Latitude")

# set ylabel
plt.ylabel("Humidity(%)")

# save the plotted figure as a png file in output data folder
plt.savefig("./output_data/northern_humidity_lat_regression.png")

# show the plot
plt.show()
# Out:
# The r-squared is : 0.35

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# use linear regression function for southern hemisphere analysis
equation = linear_regression(southern_hemisphere["Lat"], southern_hemisphere["Humidity"])

# annotate
annotate(equation, 0, 0)

# title for plot
plt.title("Southern Hemisphere - Humidity vs. Latitude Linear Regression")

# set xlabel
plt.xlabel("Latitude")

# set ylabel
plt.ylabel("Humidity(%)")

# save the plotted figure as a png file in output data folder
plt.savefig("./output_data/southern_humidity_lat_regression.png")

# show the plot
plt.show()
# Out:
# The r-squared is : 0.02

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# use linear regression function for northern hemisphere analysis
equation = linear_regression(northern_hemisphere["Lat"], northern_hemisphere["Cloudiness"])

# annotate
annotate(equation, 0, 0)

# title for plot
plt.title("Northern Hemisphere - Cloudiness vs. Latitude Linear Regression")

# set xlabel
plt.xlabel("Latitude")

# set ylabel
plt.ylabel("Cloudiness(%)")

# save the plotted figure as a png file in output data folder
plt.savefig("./output_data/northern_cloudiness_lat_regression.png")

# show the plot
plt.show()
# Out:
# The r-squared is : 0.28

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# use linear regression function for southern hemisphere analysis
equation = linear_regression(southern_hemisphere["Lat"], southern_hemisphere["Cloudiness"])

# annotate
annotate(equation, 0, 0)

# title for plot
plt.title("Southern Hemisphere - Cloudiness vs. Latitude Linear Regression")

# set xlabel
plt.xlabel("Latitude")

# set ylabel
plt.ylabel("Cloudiness(%)")

# save the plotted figure as a png file in output data folder
plt.savefig("./output_data/southern_cloudiness_lat_regression.png")

# show the plot
plt.show()
# Out:
# The r-squared is : 0.17

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# use linear regression function for northern hemisphere analysis
equation = linear_regression(northern_hemisphere["Lat"], northern_hemisphere["Wind Speed"])

# annotate
annotate(equation, 0, 0)

# title for plot
plt.title("Northern Hemisphere - Wind Speed vs. Latitude Linear Regression")

# set xlabel
plt.xlabel("Latitude")

# set ylabel
plt.ylabel("Wind Speed(mph)")

# save the plotted figure as a png file in output data folder
plt.savefig("./output_data/northern_wind_speed_lat_regression.png")

# show the plot
plt.show()
# Out:
# The r-squared is : -0.0

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# use linear regression function for southern hemisphere analysis
equation = linear_regression(southern_hemisphere["Lat"], southern_hemisphere["Wind Speed"])

# annotate
annotate(equation, 0, 0)

# title for plot
plt.title("Southern Hemisphere - Wind Speed vs. Latitude Linear Regression")

# set xlabel
plt.xlabel("Latitude")

# set ylabel
plt.ylabel("Wind Speed(mph)")

# save the plotted figure as a png file in output data folder
plt.savefig("./output_data/southern_wind_speed_lat_regression.png")

# show the plot
plt.show()
# Out:
# The r-squared is : -0.18

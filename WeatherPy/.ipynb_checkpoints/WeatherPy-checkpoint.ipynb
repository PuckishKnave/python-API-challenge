# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from datetime import datetime
from scipy.stats import linregress
import scipy.stats as st

# Import API key
import config_from_pydata_env

weather_api_key = config_from_pydata_env.weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 624

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# url for openweather api
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"

# build query url
query_url = f"{url}appid={weather_api_key}&units={units}&q="

# %%
# empty lists to hold query information
lat = []
temp = []
temp_max = []
humidity = []
wind_speed = []
lon = []
date = []
country = []
cloudiness = []


# loop through list of cities and request information
count = 0
set = 1
for city in cities:
    count = count + 1
    # using sleep here to not reach api limit
    if count == 51:
        count = 1
        set = set + 1
        time.sleep(5)
    print(f"Processing Record {count} of Set {set} | {city}")
    try:
        response = requests.get(query_url + city).json()
        lat.append(response['coord']['lat'])
        lon.append(response['coord']['lon'])
        temp.append(response['main']['temp'])
        temp_max.append(response['main']['temp_max'])
        humidity.append(response['main']['humidity'])
        wind_speed.append(response['wind']['speed'])
        date.append(response['dt'])
        country.append(response['sys']['country'])
        cloudiness.append(response['clouds']['all'])
    except:
        print("City not found. Skipping...")
        lat.append(np.nan)
        lon.append(np.nan)
        temp.append(np.nan)
        temp_max.append(np.nan)
        humidity.append(np.nan)
        wind_speed.append(np.nan)
        date.append(np.nan)
        country.append(np.nan)
        cloudiness.append(np.nan)
    continue
print("Data Retrieval Complete")
# Out:
# Processing Record 1 of Set 1 | kapaa
# Processing Record 2 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 3 of Set 1 | matale
# Processing Record 4 of Set 1 | hermanus
# Processing Record 5 of Set 1 | bluff
# Processing Record 6 of Set 1 | cape town
# Processing Record 7 of Set 1 | sechura
# Processing Record 8 of Set 1 | hilo
# Processing Record 9 of Set 1 | henties bay
# Processing Record 10 of Set 1 | maine-soroa
# Processing Record 11 of Set 1 | qaanaaq
# Processing Record 12 of Set 1 | havelock
# Processing Record 13 of Set 1 | saskylakh
# Processing Record 14 of Set 1 | denpasar
# Processing Record 15 of Set 1 | saint anthony
# Processing Record 16 of Set 1 | trairi
# Processing Record 17 of Set 1 | teguise
# Processing Record 18 of Set 1 | husavik
# Processing Record 19 of Set 1 | scarborough
# Processing Record 20 of Set 1 | necochea
# Processing Record 21 of Set 1 | deer lake
# Processing Record 22 of Set 1 | capao da canoa
# Processing Record 23 of Set 1 | tuktoyaktuk
# Processing Record 24 of Set 1 | bababe
# City not found. Skipping...
# Processing Record 25 of Set 1 | mahebourg
# Processing Record 26 of Set 1 | port elizabeth
# Processing Record 27 of Set 1 | victoria
# Processing Record 28 of Set 1 | hervey bay
# Processing Record 29 of Set 1 | alberton
# Processing Record 30 of Set 1 | busselton
# Processing Record 31 of Set 1 | punta arenas
# Processing Record 32 of Set 1 | cheuskiny
# City not found. Skipping...
# Processing Record 33 of Set 1 | rikitea
# Processing Record 34 of Set 1 | georgetown
# Processing Record 35 of Set 1 | lodwar
# Processing Record 36 of Set 1 | neiafu
# Processing Record 37 of Set 1 | hobart
# Processing Record 38 of Set 1 | albany
# Processing Record 39 of Set 1 | mackay
# Processing Record 40 of Set 1 | kruisfontein
# Processing Record 41 of Set 1 | yellowknife
# Processing Record 42 of Set 1 | hobyo
# Processing Record 43 of Set 1 | ilulissat
# Processing Record 44 of Set 1 | butaritari
# Processing Record 45 of Set 1 | sur
# Processing Record 46 of Set 1 | shubarshi
# Processing Record 47 of Set 1 | mahajanga
# Processing Record 48 of Set 1 | kavieng
# Processing Record 49 of Set 1 | ushuaia
# Processing Record 50 of Set 1 | fairbanks
# Processing Record 1 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 2 of Set 2 | snasa
# Processing Record 3 of Set 2 | atuona
# Processing Record 4 of Set 2 | kotelnich
# Processing Record 5 of Set 2 | bull savanna
# Processing Record 6 of Set 2 | magetan
# City not found. Skipping...
# Processing Record 7 of Set 2 | thompson
# Processing Record 8 of Set 2 | lima
# Processing Record 9 of Set 2 | petropavlovsk-kamchatskiy
# Processing Record 10 of Set 2 | zaozerne
# Processing Record 11 of Set 2 | bandarbeyla
# Processing Record 12 of Set 2 | njombe
# Processing Record 13 of Set 2 | bethel
# Processing Record 14 of Set 2 | chuy
# Processing Record 15 of Set 2 | chokurdakh
# Processing Record 16 of Set 2 | djambala
# Processing Record 17 of Set 2 | ola
# Processing Record 18 of Set 2 | kiruna
# Processing Record 19 of Set 2 | leningradskiy
# Processing Record 20 of Set 2 | aguas vermelhas
# Processing Record 21 of Set 2 | tuatapere
# Processing Record 22 of Set 2 | zhanaozen
# Processing Record 23 of Set 2 | tautira
# Processing Record 24 of Set 2 | port alfred
# Processing Record 25 of Set 2 | vardo
# Processing Record 26 of Set 2 | aden
# Processing Record 27 of Set 2 | berdigestyakh
# Processing Record 28 of Set 2 | cairns
# Processing Record 29 of Set 2 | blagoyevo
# Processing Record 30 of Set 2 | rio gallegos
# Processing Record 31 of Set 2 | ribeira grande
# Processing Record 32 of Set 2 | chifeng
# Processing Record 33 of Set 2 | broome
# Processing Record 34 of Set 2 | luderitz
# Processing Record 35 of Set 2 | klaksvik
# Processing Record 36 of Set 2 | rockland
# Processing Record 37 of Set 2 | puerto ayora
# Processing Record 38 of Set 2 | abu samrah
# Processing Record 39 of Set 2 | sao filipe
# Processing Record 40 of Set 2 | saldanha
# Processing Record 41 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 42 of Set 2 | vangaindrano
# Processing Record 43 of Set 2 | portland
# Processing Record 44 of Set 2 | lebu
# Processing Record 45 of Set 2 | nova olimpia
# Processing Record 46 of Set 2 | barrow
# Processing Record 47 of Set 2 | acapulco
# Processing Record 48 of Set 2 | narsaq
# Processing Record 49 of Set 2 | akhmim
# Processing Record 50 of Set 2 | yeppoon
# Processing Record 1 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 2 of Set 3 | hovd
# Processing Record 3 of Set 3 | adrar
# Processing Record 4 of Set 3 | qandala
# Processing Record 5 of Set 3 | tasiilaq
# Processing Record 6 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 7 of Set 3 | castro
# Processing Record 8 of Set 3 | torbay
# Processing Record 9 of Set 3 | dikson
# Processing Record 10 of Set 3 | vaini
# Processing Record 11 of Set 3 | nguiu
# City not found. Skipping...
# Processing Record 12 of Set 3 | lompoc
# Processing Record 13 of Set 3 | mataura
# Processing Record 14 of Set 3 | khash
# Processing Record 15 of Set 3 | teya
# Processing Record 16 of Set 3 | kushiro
# Processing Record 17 of Set 3 | nacala
# Processing Record 18 of Set 3 | tilichiki
# Processing Record 19 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 20 of Set 3 | sinnamary
# Processing Record 21 of Set 3 | mogok
# Processing Record 22 of Set 3 | noumea
# Processing Record 23 of Set 3 | usinsk
# Processing Record 24 of Set 3 | buenos aires
# Processing Record 25 of Set 3 | sandwick
# Processing Record 26 of Set 3 | ponta do sol
# Processing Record 27 of Set 3 | arraial do cabo
# Processing Record 28 of Set 3 | mayo
# Processing Record 29 of Set 3 | namatanai
# Processing Record 30 of Set 3 | chernyshevskiy
# Processing Record 31 of Set 3 | eureka
# Processing Record 32 of Set 3 | nikolskoye
# Processing Record 33 of Set 3 | basoko
# Processing Record 34 of Set 3 | mount pleasant
# Processing Record 35 of Set 3 | geraldton
# Processing Record 36 of Set 3 | nara
# Processing Record 37 of Set 3 | bennettsville
# Processing Record 38 of Set 3 | inhambane
# Processing Record 39 of Set 3 | veraval
# Processing Record 40 of Set 3 | santa catarina de tepehuanes
# Processing Record 41 of Set 3 | fort nelson
# Processing Record 42 of Set 3 | agadez
# Processing Record 43 of Set 3 | aktau
# Processing Record 44 of Set 3 | dalvik
# Processing Record 45 of Set 3 | pangody
# Processing Record 46 of Set 3 | sitka
# Processing Record 47 of Set 3 | les cayes
# Processing Record 48 of Set 3 | laguna
# Processing Record 49 of Set 3 | beringovskiy
# Processing Record 50 of Set 3 | norman wells
# Processing Record 1 of Set 4 | porto novo
# Processing Record 2 of Set 4 | port blair
# Processing Record 3 of Set 4 | new norfolk
# Processing Record 4 of Set 4 | mopti
# Processing Record 5 of Set 4 | kaitangata
# Processing Record 6 of Set 4 | nanortalik
# Processing Record 7 of Set 4 | hat yai
# Processing Record 8 of Set 4 | upata
# Processing Record 9 of Set 4 | clyde river
# Processing Record 10 of Set 4 | helmbrechts
# Processing Record 11 of Set 4 | kropotkin
# Processing Record 12 of Set 4 | taolanaro
# City not found. Skipping...
# Processing Record 13 of Set 4 | lebanon
# Processing Record 14 of Set 4 | costinesti
# Processing Record 15 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 16 of Set 4 | soyo
# Processing Record 17 of Set 4 | shitanjing
# Processing Record 18 of Set 4 | pimentel
# Processing Record 19 of Set 4 | avarua
# Processing Record 20 of Set 4 | provideniya
# Processing Record 21 of Set 4 | madison
# Processing Record 22 of Set 4 | fare
# Processing Record 23 of Set 4 | walvis bay
# Processing Record 24 of Set 4 | wellington
# Processing Record 25 of Set 4 | nassau
# Processing Record 26 of Set 4 | dores do indaia
# Processing Record 27 of Set 4 | talnakh
# Processing Record 28 of Set 4 | providencia
# Processing Record 29 of Set 4 | jamestown
# Processing Record 30 of Set 4 | la reforma
# Processing Record 31 of Set 4 | bredasdorp
# Processing Record 32 of Set 4 | shizukuishi
# Processing Record 33 of Set 4 | carnarvon
# Processing Record 34 of Set 4 | phalaborwa
# Processing Record 35 of Set 4 | carutapera
# Processing Record 36 of Set 4 | tabas
# Processing Record 37 of Set 4 | karratha
# Processing Record 38 of Set 4 | khatanga
# Processing Record 39 of Set 4 | yichang
# Processing Record 40 of Set 4 | touros
# Processing Record 41 of Set 4 | ahipara
# Processing Record 42 of Set 4 | hasaki
# Processing Record 43 of Set 4 | los llanos de aridane
# Processing Record 44 of Set 4 | paramonga
# Processing Record 45 of Set 4 | saint george
# Processing Record 46 of Set 4 | pauini
# Processing Record 47 of Set 4 | baykit
# Processing Record 48 of Set 4 | bokspits
# City not found. Skipping...
# Processing Record 49 of Set 4 | shagonar
# Processing Record 50 of Set 4 | yulara
# Processing Record 1 of Set 5 | tuensang
# Processing Record 2 of Set 5 | ambon
# Processing Record 3 of Set 5 | ixtapa
# Processing Record 4 of Set 5 | ciudad bolivar
# Processing Record 5 of Set 5 | omsukchan
# Processing Record 6 of Set 5 | esperance
# Processing Record 7 of Set 5 | te anau
# Processing Record 8 of Set 5 | longyearbyen
# Processing Record 9 of Set 5 | chapais
# Processing Record 10 of Set 5 | iskateley
# Processing Record 11 of Set 5 | los alamos
# Processing Record 12 of Set 5 | alyangula
# Processing Record 13 of Set 5 | dingle
# Processing Record 14 of Set 5 | fort wellington
# Processing Record 15 of Set 5 | lithakia
# Processing Record 16 of Set 5 | vao
# Processing Record 17 of Set 5 | baghdad
# Processing Record 18 of Set 5 | usakos
# Processing Record 19 of Set 5 | tombouctou
# Processing Record 20 of Set 5 | pacific grove
# Processing Record 21 of Set 5 | moroni
# Processing Record 22 of Set 5 | orel
# Processing Record 23 of Set 5 | campos do jordao
# Processing Record 24 of Set 5 | conceicao do araguaia
# Processing Record 25 of Set 5 | belvedere marittimo
# Processing Record 26 of Set 5 | hirara
# Processing Record 27 of Set 5 | aklavik
# Processing Record 28 of Set 5 | port said
# Processing Record 29 of Set 5 | turkistan
# Processing Record 30 of Set 5 | bathsheba
# Processing Record 31 of Set 5 | potam
# Processing Record 32 of Set 5 | ginir
# Processing Record 33 of Set 5 | ancud
# Processing Record 34 of Set 5 | luba
# Processing Record 35 of Set 5 | mar del plata
# Processing Record 36 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 37 of Set 5 | saint-philippe
# Processing Record 38 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 39 of Set 5 | la ronge
# Processing Record 40 of Set 5 | port charlotte
# Processing Record 41 of Set 5 | abha
# Processing Record 42 of Set 5 | metu
# Processing Record 43 of Set 5 | conceicao da barra
# Processing Record 44 of Set 5 | katherine
# Processing Record 45 of Set 5 | praia da vitoria
# Processing Record 46 of Set 5 | bayangol
# Processing Record 47 of Set 5 | luwuk
# Processing Record 48 of Set 5 | lavrentiya
# Processing Record 49 of Set 5 | vyazma
# Processing Record 50 of Set 5 | dzhebariki-khaya
# Processing Record 1 of Set 6 | darlowo
# Processing Record 2 of Set 6 | cadillac
# Processing Record 3 of Set 6 | mocambique
# City not found. Skipping...
# Processing Record 4 of Set 6 | saint-augustin
# Processing Record 5 of Set 6 | binzhou
# Processing Record 6 of Set 6 | sumter
# Processing Record 7 of Set 6 | pangnirtung
# Processing Record 8 of Set 6 | tulu bolo
# Processing Record 9 of Set 6 | kodiak
# Processing Record 10 of Set 6 | guerrero negro
# Processing Record 11 of Set 6 | cockburn town
# Processing Record 12 of Set 6 | fort morgan
# Processing Record 13 of Set 6 | puerto del rosario
# Processing Record 14 of Set 6 | rundu
# Processing Record 15 of Set 6 | dudinka
# Processing Record 16 of Set 6 | severo-kurilsk
# Processing Record 17 of Set 6 | fukue
# Processing Record 18 of Set 6 | halle
# Processing Record 19 of Set 6 | fomboni
# Processing Record 20 of Set 6 | beloha
# Processing Record 21 of Set 6 | aykhal
# Processing Record 22 of Set 6 | tomigusuku
# Processing Record 23 of Set 6 | paamiut
# Processing Record 24 of Set 6 | kochinda
# Processing Record 25 of Set 6 | swan hill
# Processing Record 26 of Set 6 | auki
# Processing Record 27 of Set 6 | pila
# Processing Record 28 of Set 6 | port hardy
# Processing Record 29 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 30 of Set 6 | svay rieng
# Processing Record 31 of Set 6 | capreol
# Processing Record 32 of Set 6 | nouadhibou
# Processing Record 33 of Set 6 | stornoway
# Processing Record 34 of Set 6 | samarai
# Processing Record 35 of Set 6 | dolinsk
# Processing Record 36 of Set 6 | taltal
# Processing Record 37 of Set 6 | kaseda
# Processing Record 38 of Set 6 | barentsburg
# City not found. Skipping...
# Processing Record 39 of Set 6 | contamana
# Processing Record 40 of Set 6 | marysville
# Processing Record 41 of Set 6 | bengkulu
# Processing Record 42 of Set 6 | kuytun
# Processing Record 43 of Set 6 | donskoye
# Processing Record 44 of Set 6 | boralday
# Processing Record 45 of Set 6 | wailuku
# Processing Record 46 of Set 6 | yinchuan
# Processing Record 47 of Set 6 | faanui
# Processing Record 48 of Set 6 | punta alta
# Processing Record 49 of Set 6 | takoradi
# Processing Record 50 of Set 6 | hithadhoo
# Processing Record 1 of Set 7 | sao gabriel da cachoeira
# Processing Record 2 of Set 7 | wilmington
# Processing Record 3 of Set 7 | east london
# Processing Record 4 of Set 7 | christchurch
# Processing Record 5 of Set 7 | roald
# Processing Record 6 of Set 7 | upernavik
# Processing Record 7 of Set 7 | kieta
# Processing Record 8 of Set 7 | bam
# Processing Record 9 of Set 7 | sabinopolis
# Processing Record 10 of Set 7 | aleysk
# Processing Record 11 of Set 7 | fortuna
# Processing Record 12 of Set 7 | port lincoln
# Processing Record 13 of Set 7 | kamalpur
# Processing Record 14 of Set 7 | savannah bight
# Processing Record 15 of Set 7 | mashhad
# Processing Record 16 of Set 7 | nizwa
# Processing Record 17 of Set 7 | kulhudhuffushi
# Processing Record 18 of Set 7 | wencheng
# Processing Record 19 of Set 7 | matara
# Processing Record 20 of Set 7 | half moon bay
# Processing Record 21 of Set 7 | katsuura
# Processing Record 22 of Set 7 | cidreira
# Processing Record 23 of Set 7 | uzyn
# Processing Record 24 of Set 7 | imbituba
# Processing Record 25 of Set 7 | lorengau
# Processing Record 26 of Set 7 | araouane
# Processing Record 27 of Set 7 | pevek
# Processing Record 28 of Set 7 | santa isabel do rio negro
# Processing Record 29 of Set 7 | lata
# Processing Record 30 of Set 7 | yurginskoye
# Processing Record 31 of Set 7 | san bartolome de tirajana
# Processing Record 32 of Set 7 | nuuk
# Processing Record 33 of Set 7 | tumannyy
# City not found. Skipping...
# Processing Record 34 of Set 7 | weiz
# Processing Record 35 of Set 7 | ipixuna
# Processing Record 36 of Set 7 | gornji milanovac
# Processing Record 37 of Set 7 | ejido
# Processing Record 38 of Set 7 | genhe
# Processing Record 39 of Set 7 | margate
# Processing Record 40 of Set 7 | haines junction
# Processing Record 41 of Set 7 | buala
# Processing Record 42 of Set 7 | lagoa
# Processing Record 43 of Set 7 | nosy varika
# Processing Record 44 of Set 7 | zabol
# Processing Record 45 of Set 7 | cayenne
# Processing Record 46 of Set 7 | tura
# Processing Record 47 of Set 7 | kalmunai
# Processing Record 48 of Set 7 | mollendo
# Processing Record 49 of Set 7 | consett
# Processing Record 50 of Set 7 | muzhi
# Processing Record 1 of Set 8 | pichayevo
# Processing Record 2 of Set 8 | arman
# Processing Record 3 of Set 8 | makokou
# Processing Record 4 of Set 8 | phetchaburi
# Processing Record 5 of Set 8 | saint-francois
# Processing Record 6 of Set 8 | warqla
# City not found. Skipping...
# Processing Record 7 of Set 8 | rongcheng
# Processing Record 8 of Set 8 | superior
# Processing Record 9 of Set 8 | bambous virieux
# Processing Record 10 of Set 8 | pisco
# Processing Record 11 of Set 8 | muhos
# Processing Record 12 of Set 8 | liverpool
# Processing Record 13 of Set 8 | ilabaya
# Processing Record 14 of Set 8 | isangel
# Processing Record 15 of Set 8 | komsomolskiy
# Processing Record 16 of Set 8 | sola
# Processing Record 17 of Set 8 | tunduru
# City not found. Skipping...
# Processing Record 18 of Set 8 | rengasdengklok
# Processing Record 19 of Set 8 | coahuayana
# Processing Record 20 of Set 8 | mogadishu
# Processing Record 21 of Set 8 | vendychany
# Processing Record 22 of Set 8 | livadiya
# Processing Record 23 of Set 8 | pagudpud
# Processing Record 24 of Set 8 | nome
# Processing Record 25 of Set 8 | cabo san lucas
# Processing Record 26 of Set 8 | umzimvubu
# City not found. Skipping...
# Processing Record 27 of Set 8 | meulaboh
# Processing Record 28 of Set 8 | gat
# Processing Record 29 of Set 8 | itapora
# Processing Record 30 of Set 8 | cortez
# Processing Record 31 of Set 8 | ruyigi
# Processing Record 32 of Set 8 | le port
# Processing Record 33 of Set 8 | egvekinot
# Processing Record 34 of Set 8 | sitrah
# Processing Record 35 of Set 8 | sydney
# Processing Record 36 of Set 8 | palu
# Processing Record 37 of Set 8 | carman
# Processing Record 38 of Set 8 | kahului
# Processing Record 39 of Set 8 | garowe
# Processing Record 40 of Set 8 | skibotn
# Processing Record 41 of Set 8 | gabu
# Processing Record 42 of Set 8 | saint andrews
# Processing Record 43 of Set 8 | florianopolis
# Processing Record 44 of Set 8 | airai
# Processing Record 45 of Set 8 | vestmannaeyjar
# Processing Record 46 of Set 8 | baruun-urt
# Processing Record 47 of Set 8 | souillac
# Processing Record 48 of Set 8 | mahadday weyne
# City not found. Skipping...
# Processing Record 49 of Set 8 | roma
# Processing Record 50 of Set 8 | tocopilla
# Processing Record 1 of Set 9 | nizhneyansk
# City not found. Skipping...
# Processing Record 2 of Set 9 | buraydah
# Processing Record 3 of Set 9 | talaya
# Processing Record 4 of Set 9 | barra
# Processing Record 5 of Set 9 | faya
# Processing Record 6 of Set 9 | tiksi
# Processing Record 7 of Set 9 | krasnoarmeysk
# Processing Record 8 of Set 9 | abu dhabi
# Processing Record 9 of Set 9 | taketa
# Processing Record 10 of Set 9 | shimoda
# Processing Record 11 of Set 9 | tabou
# Processing Record 12 of Set 9 | conde
# Processing Record 13 of Set 9 | vila do maio
# Processing Record 14 of Set 9 | shiraoi
# Processing Record 15 of Set 9 | lesnoy
# Processing Record 16 of Set 9 | niksic
# Processing Record 17 of Set 9 | bara
# Processing Record 18 of Set 9 | jalu
# Processing Record 19 of Set 9 | venezuela
# Processing Record 20 of Set 9 | pressbaum
# Processing Record 21 of Set 9 | plettenberg bay
# Processing Record 22 of Set 9 | gacko
# Processing Record 23 of Set 9 | mareeba
# Processing Record 24 of Set 9 | iqaluit
# Processing Record 25 of Set 9 | codrington
# Processing Record 26 of Set 9 | tromso
# Processing Record 27 of Set 9 | makung
# City not found. Skipping...
# Processing Record 28 of Set 9 | dubrovnik
# Processing Record 29 of Set 9 | gresik
# Processing Record 30 of Set 9 | borama
# City not found. Skipping...
# Processing Record 31 of Set 9 | alpena
# Processing Record 32 of Set 9 | cockburn harbour
# City not found. Skipping...
# Processing Record 33 of Set 9 | kadykchan
# City not found. Skipping...
# Processing Record 34 of Set 9 | kampene
# Processing Record 35 of Set 9 | temiscaming
# Processing Record 36 of Set 9 | kuche
# City not found. Skipping...
# Processing Record 37 of Set 9 | wagar
# Processing Record 38 of Set 9 | xihua
# Processing Record 39 of Set 9 | hofn
# Processing Record 40 of Set 9 | mackenzie
# Processing Record 41 of Set 9 | barao de melgaco
# Processing Record 42 of Set 9 | tahe
# Processing Record 43 of Set 9 | bundaberg
# Processing Record 44 of Set 9 | sao jose da coroa grande
# Processing Record 45 of Set 9 | sandy point
# Processing Record 46 of Set 9 | flin flon
# Processing Record 47 of Set 9 | vaitape
# Processing Record 48 of Set 9 | yarim
# Processing Record 49 of Set 9 | novosokolniki
# Processing Record 50 of Set 9 | riyadh
# Processing Record 1 of Set 10 | matamoros
# Processing Record 2 of Set 10 | sapele
# Processing Record 3 of Set 10 | sedelnikovo
# City not found. Skipping...
# Processing Record 4 of Set 10 | kamenka
# Processing Record 5 of Set 10 | rosetown
# Processing Record 6 of Set 10 | albanel
# Processing Record 7 of Set 10 | nouakchott
# Processing Record 8 of Set 10 | de aar
# Processing Record 9 of Set 10 | valparaiso
# Processing Record 10 of Set 10 | axim
# Processing Record 11 of Set 10 | vila velha
# Processing Record 12 of Set 10 | san francisco
# Processing Record 13 of Set 10 | tuscaloosa
# Processing Record 14 of Set 10 | zhob
# Processing Record 15 of Set 10 | le creusot
# Processing Record 16 of Set 10 | flinders
# Processing Record 17 of Set 10 | porbandar
# Processing Record 18 of Set 10 | zhigansk
# Processing Record 19 of Set 10 | panlaitan
# Processing Record 20 of Set 10 | santa comba
# Processing Record 21 of Set 10 | santa fe
# Processing Record 22 of Set 10 | ndele
# Processing Record 23 of Set 10 | hushitai
# Processing Record 24 of Set 10 | karaul
# City not found. Skipping...
# Processing Record 25 of Set 10 | san alberto
# Processing Record 26 of Set 10 | madimba
# Processing Record 27 of Set 10 | itacoatiara
# Processing Record 28 of Set 10 | cumberland
# Processing Record 29 of Set 10 | yeletskiy
# City not found. Skipping...
# Processing Record 30 of Set 10 | hansot
# Processing Record 31 of Set 10 | ouallam
# Processing Record 32 of Set 10 | sept-iles
# Processing Record 33 of Set 10 | bereda
# Processing Record 34 of Set 10 | amos
# Processing Record 35 of Set 10 | nalut
# Processing Record 36 of Set 10 | formoso do araguaia
# City not found. Skipping...
# Processing Record 37 of Set 10 | kamaishi
# Processing Record 38 of Set 10 | wuwei
# Processing Record 39 of Set 10 | poum
# Processing Record 40 of Set 10 | ribas do rio pardo
# Processing Record 41 of Set 10 | wasilla
# Processing Record 42 of Set 10 | bar harbor
# Processing Record 43 of Set 10 | pontianak
# Processing Record 44 of Set 10 | nanga eboko
# Processing Record 45 of Set 10 | anqing
# Processing Record 46 of Set 10 | peterhead
# Processing Record 47 of Set 10 | quimper
# Processing Record 48 of Set 10 | uray
# Processing Record 49 of Set 10 | qaqortoq
# Processing Record 50 of Set 10 | casaluce
# Processing Record 1 of Set 11 | kristinehamn
# Processing Record 2 of Set 11 | karamea
# City not found. Skipping...
# Processing Record 3 of Set 11 | wanxian
# Processing Record 4 of Set 11 | kaeo
# Processing Record 5 of Set 11 | ivolginsk
# Processing Record 6 of Set 11 | kracheh
# City not found. Skipping...
# Processing Record 7 of Set 11 | lahaina
# Processing Record 8 of Set 11 | hokitika
# Processing Record 9 of Set 11 | simav
# Processing Record 10 of Set 11 | salalah
# Processing Record 11 of Set 11 | shingu
# Processing Record 12 of Set 11 | udachnyy
# Processing Record 13 of Set 11 | ulladulla
# Processing Record 14 of Set 11 | bambanglipuro
# Processing Record 15 of Set 11 | coquimbo
# Processing Record 16 of Set 11 | vanimo
# Processing Record 17 of Set 11 | gilgit
# Processing Record 18 of Set 11 | tchollire
# Processing Record 19 of Set 11 | alice town
# Processing Record 20 of Set 11 | corrente
# Processing Record 21 of Set 11 | gori
# Processing Record 22 of Set 11 | oranjemund
# Processing Record 23 of Set 11 | pemangkat
# Processing Record 24 of Set 11 | nikki
# Processing Record 25 of Set 11 | alta floresta
# Processing Record 26 of Set 11 | nishihara
# Processing Record 27 of Set 11 | pangai
# Processing Record 28 of Set 11 | kavaratti
# Processing Record 29 of Set 11 | honiara
# Processing Record 30 of Set 11 | nicoya
# Processing Record 31 of Set 11 | nakapiripirit
# Processing Record 32 of Set 11 | ceara-mirim
# City not found. Skipping...
# Processing Record 33 of Set 11 | belaya gora
# Processing Record 34 of Set 11 | tadine
# Processing Record 35 of Set 11 | stromness
# Processing Record 36 of Set 11 | yerbogachen
# Processing Record 37 of Set 11 | uyuni
# Processing Record 38 of Set 11 | san cristobal
# Processing Record 39 of Set 11 | bolitoc
# Processing Record 40 of Set 11 | ilhabela
# Processing Record 41 of Set 11 | padang
# Processing Record 42 of Set 11 | tunceli
# Processing Record 43 of Set 11 | klyuchevskiy
# Processing Record 44 of Set 11 | amderma
# City not found. Skipping...
# Processing Record 45 of Set 11 | chunskiy
# Processing Record 46 of Set 11 | funehiki
# Processing Record 47 of Set 11 | tutoia
# Processing Record 48 of Set 11 | lumeje
# Processing Record 49 of Set 11 | sovetskiy
# Processing Record 50 of Set 11 | viedma
# Processing Record 1 of Set 12 | milton
# Processing Record 2 of Set 12 | san jose
# Processing Record 3 of Set 12 | nemuro
# Processing Record 4 of Set 12 | san isidro
# Processing Record 5 of Set 12 | martapura
# Processing Record 6 of Set 12 | tigil
# Processing Record 7 of Set 12 | paita
# Processing Record 8 of Set 12 | yuza
# Processing Record 9 of Set 12 | quesnel
# Processing Record 10 of Set 12 | dzilam gonzalez
# Processing Record 11 of Set 12 | chumikan
# Processing Record 12 of Set 12 | karaton
# Processing Record 13 of Set 12 | verkhnevilyuysk
# Processing Record 14 of Set 12 | batsfjord
# Processing Record 15 of Set 12 | atar
# Processing Record 16 of Set 12 | tarakan
# Processing Record 17 of Set 12 | mandalgovi
# Processing Record 18 of Set 12 | sarai sidhu
# Processing Record 19 of Set 12 | oktyabrskiy
# Processing Record 20 of Set 12 | madera
# Processing Record 21 of Set 12 | quatre cocos
# Processing Record 22 of Set 12 | macheng
# Processing Record 23 of Set 12 | greencastle
# Processing Record 24 of Set 12 | aksarayskiy
# Processing Record 25 of Set 12 | xining
# Processing Record 26 of Set 12 | thinadhoo
# Processing Record 27 of Set 12 | sayula
# Processing Record 28 of Set 12 | buchanan
# Processing Record 29 of Set 12 | hurricane
# Processing Record 30 of Set 12 | ishigaki
# Processing Record 31 of Set 12 | san marcos
# Processing Record 32 of Set 12 | rawson
# Processing Record 33 of Set 12 | kamiiso
# Processing Record 34 of Set 12 | mount gambier
# Processing Record 35 of Set 12 | trebinje
# Processing Record 36 of Set 12 | kudahuvadhoo
# Processing Record 37 of Set 12 | tres arroyos
# Processing Record 38 of Set 12 | avera
# Processing Record 39 of Set 12 | batagay
# Processing Record 40 of Set 12 | itupiranga
# Processing Record 41 of Set 12 | road town
# Processing Record 42 of Set 12 | port augusta
# Processing Record 43 of Set 12 | maragogi
# Processing Record 44 of Set 12 | mimongo
# Processing Record 45 of Set 12 | hambantota
# Processing Record 46 of Set 12 | varnamo
# Processing Record 47 of Set 12 | rupert
# Processing Record 48 of Set 12 | visconde do rio branco
# Processing Record 49 of Set 12 | wangkui
# Processing Record 50 of Set 12 | nioki
# Processing Record 1 of Set 13 | marawi
# Processing Record 2 of Set 13 | morros
# Processing Record 3 of Set 13 | tres picos
# Processing Record 4 of Set 13 | narino
# Processing Record 5 of Set 13 | delijan
# Processing Record 6 of Set 13 | sorvag
# City not found. Skipping...
# Processing Record 7 of Set 13 | the valley
# Processing Record 8 of Set 13 | saint-pierre
# Processing Record 9 of Set 13 | ibaiti
# Processing Record 10 of Set 13 | palabuhanratu
# City not found. Skipping...
# Processing Record 11 of Set 13 | kihei
# Processing Record 12 of Set 13 | sayyan
# Processing Record 13 of Set 13 | antofagasta
# Processing Record 14 of Set 13 | mau
# Processing Record 15 of Set 13 | srednekolymsk
# Processing Record 16 of Set 13 | hornepayne
# Processing Record 17 of Set 13 | morant bay
# Processing Record 18 of Set 13 | hengyang
# Processing Record 19 of Set 13 | victoria point
# Processing Record 20 of Set 13 | biak
# Processing Record 21 of Set 13 | cozumel
# Processing Record 22 of Set 13 | comodoro rivadavia
# Processing Record 23 of Set 13 | rudbar
# Processing Record 24 of Set 13 | kutum
# Data Retrieval Complete

# %%
len(lat)
# Out:
# 624

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# convert raw data to dataframe
city_weather_df = pd.DataFrame({
    "City": cities,
    "Lat": lat,
    "Lng": lon,
    "Max Temp": temp_max,
    "Humidity": humidity,
    "Cloudiness": cloudiness,
    "Wind Speed": wind_speed,
    "Country": country,
    "Date": date,
})

# drop cities that were skipped because they could not be found by the api
city_weather_df = city_weather_df.dropna(how="any")

# %%
# export the city data into a .csv file within a folder named output_data
city_weather_df.to_csv("./output_data/city_weather_data.csv", index=False)

# display the dataframe
city_weather_df
# Out:
#                    City    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0                 kapaa  22.08 -159.32     73.00      79.0        46.0
# 2                matale   7.47   80.62     72.07      86.0        10.0
# 3              hermanus -34.42   19.23     60.01      71.0         0.0
# 4                 bluff -46.60  168.33     43.00      88.0        92.0
# 5             cape town -33.93   18.42     62.60      51.0         2.0
# ..                  ...    ...     ...       ...       ...         ...
# 619                biak  -0.91  122.88     76.53      70.0        81.0
# 620             cozumel  20.51  -86.95     84.20      83.0        75.0
# 621  comodoro rivadavia -45.87  -67.50     53.60      46.0         0.0
# 622              rudbar  30.15   62.60     60.80      27.0         0.0
# 623               kutum  14.20   24.67     82.54      14.0         8.0
#
#      Wind Speed Country          Date
# 0          8.55      US  1.603212e+09
# 2          4.54      LK  1.603212e+09
# 3          1.99      ZA  1.603212e+09
# 4         12.77      NZ  1.603212e+09
# 5         17.22      ZA  1.603212e+09
# ..          ...     ...           ...
# 619        7.00      ID  1.603212e+09
# 620        3.36      MX  1.603212e+09
# 621       12.75      AR  1.603212e+09
# 622        4.54      AF  1.603212e+09
# 623       12.73      SD  1.603212e+09
#
# [585 rows x 9 columns]

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#  Get the indices of cities that have humidity over 100%.

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
# set date time variable for title
date_time = datetime.date(datetime.now())

# create latitude vs temperature scatter plot
plt.scatter(city_weather_df["Lat"], city_weather_df["Max Temp"], facecolor = "c", edgecolor = "k")

# set title
plt.title(f"City Latitude vs Max Temperature{date_time}")

# set x axis label
plt.xlabel("Latitude")

# set y axis label
plt.ylabel("Max Temperature (F)")

# set grid line
plt.grid(linestyle='-', linewidth=1, alpha = 0.5)

# save the plotted figure as a png file in output data folder
plt.savefig("./output_data/city_latitude_temperature.png")

# show the scatterplot
plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
# create latitude vs humidity scatter plot
plt.scatter(city_weather_df["Lat"], city_weather_df["Humidity"], facecolor = "c", edgecolor = "k")

# set title
plt.title(f"City Latitude vs Humidity{date_time}")

# set x axis label
plt.xlabel("Latitude")

# set y axis label
plt.ylabel('Humidity (%)')

# set grid line
plt.grid(linestyle='-', linewidth=1, alpha = 0.5)

# save the plotted figure as a png file in output data folder
plt.savefig("./output_data/city_latitude_humidity.png")

# show the scatterplot
plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
# create latitude vs cloudiness scatter plot
plt.scatter(city_weather_df["Lat"], city_weather_df["Cloudiness"], facecolor = "c", edgecolor = "k")

# set title
plt.title(f"City Latitude vs Cloudiness{date_time}")

# set x axis label
plt.xlabel("Latitude")

# set y axis label
plt.ylabel('Cloudiness(%)')

# set grid line
plt.grid(linestyle='-', linewidth=1, alpha = 0.5)

# save the plotted figure as a png file in output data folder
plt.savefig("./output_data/city_latitude_cloudiness.png")

# show the scatterplot
plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
# create latitude vs wind speed scatter plot
plt.scatter(city_weather_df["Lat"], city_weather_df["Wind Speed"], facecolor = "c", edgecolor = "k")

# set title
plt.title(f"City Latitude vs Wind Speed{date_time}")

# set x axis label
plt.xlabel("Latitude")

# set y axis label
plt.ylabel('Wind Speed(mph)')

# set grid line
plt.grid(linestyle='-', linewidth=1, alpha = 0.5)

# save the plotted figure as a png file in output data folder
plt.savefig("./output_data/city_latitude_wind_speed.png")

# show the scatterplot
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
# northern and southern hemisphere dataframes
northern_hemisphere = city_weather_df.loc[city_weather_df["Lat"] >= 0]
southern_hemisphere = city_weather_df.loc[city_weather_df["Lat"] < 0]

# define linear regression and scatterplot function
def linear_regression(x,y):
    print(f"The r-squared is : {round(st.pearsonr(x, y)[0],2)}")
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
    regress_values = x * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    plt.scatter(x, y)
    plt.plot(x,regress_values,"r-")
    return line_eq

# function for annotation
def annotate(line_eq, a, b):
    plt.annotate(line_eq,(a,b),fontsize=15,color="red")

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# use linear regression function for northern hempisphere analysis
equation = linear_regression(northern_hemisphere["Lat"], northern_hemisphere["Max Temp"])

# annotate
annotate(equation, 0, 0)

# title for plot
plt.title("Northern Hemisphere - Max Temp vs. Latitude Linear Regression")

# set xlabel
plt.xlabel("Latitude")

# set ylabel
plt.ylabel("Max Temp (F)")

# save the plotted figure as a png file in output data folder
plt.savefig("./output_data/northern_temp_lat_regression.png")

# show the plot
plt.show()
# Out:
# The r-squared is : -0.88

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# use linear regression function for southern hempisphere analysis
equation = linear_regression(southern_hemisphere["Lat"], southern_hemisphere["Max Temp"])

# annotate
annotate(equation, 0, 0)

# title for plot
plt.title("Southern Hemisphere - Max Temp vs. Latitude Linear Regression")

# set xlabel
plt.xlabel("Latitude")

# set ylabel
plt.ylabel("Max Temp(F)")

# save the plotted figure as a png file in output data folder
plt.savefig("./output_data/southern_temp_lat_regression.png")

# show the plot
plt.show()
# Out:
# The r-squared is : 0.76

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# use linear regression function for northern hemisphere analysis
equation = linear_regression(northern_hemisphere["Lat"], northern_hemisphere["Humidity"])

# annotate
annotate(equation, 0, 0)

# title for plot
plt.title("Northern Hemisphere - Humidity vs. Latitude Linear Regression")

# set xlabel
plt.xlabel("Latitude")

# set ylabel
plt.ylabel("Humidity(%)")

# save the plotted figure as a png file in output data folder
plt.savefig("./output_data/northern_humidity_lat_regression.png")

# show the plot
plt.show()
# Out:
# The r-squared is : 0.39

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# use linear regression function for southern hemisphere analysis
equation = linear_regression(southern_hemisphere["Lat"], southern_hemisphere["Humidity"])

# annotate
annotate(equation, 0, 0)

# title for plot
plt.title("Southern Hemisphere - Humidity vs. Latitude Linear Regression")

# set xlabel
plt.xlabel("Latitude")

# set ylabel
plt.ylabel("Humidity(%)")

# save the plotted figure as a png file in output data folder
plt.savefig("./output_data/southern_humidity_lat_regression.png")

# show the plot
plt.show()
# Out:
# The r-squared is : 0.04

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# use linear regression function for northern hemisphere analysis
equation = linear_regression(northern_hemisphere["Lat"], northern_hemisphere["Cloudiness"])

# annotate
annotate(equation, 0, 0)

# title for plot
plt.title("Northern Hemisphere - Cloudiness vs. Latitude Linear Regression")

# set xlabel
plt.xlabel("Latitude")

# set ylabel
plt.ylabel("Cloudiness(%)")

# save the plotted figure as a png file in output data folder
plt.savefig("./output_data/northern_cloudiness_lat_regression.png")

# show the plot
plt.show()
# Out:
# The r-squared is : 0.29

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# use linear regression function for southern hemisphere analysis
equation = linear_regression(southern_hemisphere["Lat"], southern_hemisphere["Cloudiness"])

# annotate
annotate(equation, 0, 0)

# title for plot
plt.title("Southern Hemisphere - Cloudiness vs. Latitude Linear Regression")

# set xlabel
plt.xlabel("Latitude")

# set ylabel
plt.ylabel("Cloudiness(%)")

# save the plotted figure as a png file in output data folder
plt.savefig("./output_data/southern_cloudiness_lat_regression.png")

# show the plot
plt.show()
# Out:
# The r-squared is : 0.12

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# use linear regression function for northern hemisphere analysis
equation = linear_regression(northern_hemisphere["Lat"], northern_hemisphere["Wind Speed"])

# annotate
annotate(equation, 0, 0)

# title for plot
plt.title("Northern Hemisphere - Wind Speed vs. Latitude Linear Regression")

# set xlabel
plt.xlabel("Latitude")

# set ylabel
plt.ylabel("Wind Speed(mph)")

# save the plotted figure as a png file in output data folder
plt.savefig("./output_data/northern_wind_speed_lat_regression.png")

# show the plot
plt.show()
# Out:
# The r-squared is : -0.03

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# use linear regression function for southern hemisphere analysis
equation = linear_regression(southern_hemisphere["Lat"], southern_hemisphere["Wind Speed"])

# annotate
annotate(equation, 0, 0)

# title for plot
plt.title("Northern Hemisphere - Wind Speed vs. Latitude Linear Regression")

# set xlabel
plt.xlabel("Latitude")

# set ylabel
plt.ylabel("Wind Speed(mph)")

# save the plotted figure as a png file in output data folder
plt.savefig("./output_data/southern_wind_speed_lat_regression.png")

# show the plot
plt.show()
# Out:
# The r-squared is : -0.23

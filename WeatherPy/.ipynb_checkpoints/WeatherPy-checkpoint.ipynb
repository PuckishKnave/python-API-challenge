# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from datetime import datetime
from scipy.stats import linregress
import scipy.stats as st

# Import API key
import config_from_pydata_env

weather_api_key = config_from_pydata_env.weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 622

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# url for openweather api
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"

# build query url
query_url = f"{url}appid={weather_api_key}&units={units}&q="
#query_url = url + "appid=" + weather_api_key + "&q=" + city

# %%
# empty lists to hold query information
lat = []
temp = []
temp_max = []
humidity = []
wind_speed = []
lon = []
date = []
country = []
cloudiness = []


# loop through list of cities and request information
count = 0
set = 1
for city in cities:
    count = count + 1
    # using sleep here to not reach api limit
    if count == 51:
        count = 1
        set = set + 1
        time.sleep(5)
    print(f"Processing Record {count} of Set {set} | {city}")
    try:
        response = requests.get(query_url + city).json()
        lat.append(response['coord']['lat'])
        lon.append(response['coord']['lon'])
        temp.append(response['main']['temp'])
        temp_max.append(response['main']['temp_max'])
        humidity.append(response['main']['humidity'])
        wind_speed.append(response['wind']['speed'])
        date.append(response['dt'])
        country.append(response['sys']['country'])
        cloudiness.append(response['clouds']['all'])
    except:
        print("City not found. Skipping...")
        lat.append(np.nan)
        lon.append(np.nan)
        temp.append(np.nan)
        temp_max.append(np.nan)
        humidity.append(np.nan)
        wind_speed.append(np.nan)
        date.append(np.nan)
        country.append(np.nan)
        cloudiness.append(np.nan)
    continue
print("Data Retrieval Complete")
# Out:
# Processing Record 1 of Set 1 | castro
# Processing Record 2 of Set 1 | maragogi
# Processing Record 3 of Set 1 | marzuq
# Processing Record 4 of Set 1 | dikson
# Processing Record 5 of Set 1 | georgetown
# Processing Record 6 of Set 1 | busselton
# Processing Record 7 of Set 1 | cape town
# Processing Record 8 of Set 1 | kudahuvadhoo
# Processing Record 9 of Set 1 | roma
# Processing Record 10 of Set 1 | rikitea
# Processing Record 11 of Set 1 | ponta do sol
# Processing Record 12 of Set 1 | norman wells
# Processing Record 13 of Set 1 | krasnoarmeyskiy
# Processing Record 14 of Set 1 | amalfi
# Processing Record 15 of Set 1 | east london
# Processing Record 16 of Set 1 | cidreira
# Processing Record 17 of Set 1 | hithadhoo
# Processing Record 18 of Set 1 | ketchikan
# Processing Record 19 of Set 1 | lebu
# Processing Record 20 of Set 1 | ushuaia
# Processing Record 21 of Set 1 | ukiah
# Processing Record 22 of Set 1 | mataura
# Processing Record 23 of Set 1 | qaanaaq
# Processing Record 24 of Set 1 | ponta delgada
# Processing Record 25 of Set 1 | were ilu
# Processing Record 26 of Set 1 | hilo
# Processing Record 27 of Set 1 | bonavista
# Processing Record 28 of Set 1 | tuktoyaktuk
# Processing Record 29 of Set 1 | new norfolk
# Processing Record 30 of Set 1 | clyde river
# Processing Record 31 of Set 1 | atuona
# Processing Record 32 of Set 1 | saskylakh
# Processing Record 33 of Set 1 | tautira
# Processing Record 34 of Set 1 | bluff
# Processing Record 35 of Set 1 | nikolskoye
# Processing Record 36 of Set 1 | paradwip
# City not found. Skipping...
# Processing Record 37 of Set 1 | baoqing
# Processing Record 38 of Set 1 | chicama
# Processing Record 39 of Set 1 | puerto ayora
# Processing Record 40 of Set 1 | abdulino
# Processing Record 41 of Set 1 | butaritari
# Processing Record 42 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 43 of Set 1 | hami
# Processing Record 44 of Set 1 | pevek
# Processing Record 45 of Set 1 | souillac
# Processing Record 46 of Set 1 | san pedro
# Processing Record 47 of Set 1 | zagare
# Processing Record 48 of Set 1 | albany
# Processing Record 49 of Set 1 | provideniya
# Processing Record 50 of Set 1 | sao joao da barra
# Processing Record 1 of Set 2 | tiksi
# Processing Record 2 of Set 2 | votkinsk
# Processing Record 3 of Set 2 | benha
# City not found. Skipping...
# Processing Record 4 of Set 2 | oxkutzcab
# Processing Record 5 of Set 2 | mar del plata
# Processing Record 6 of Set 2 | umm lajj
# Processing Record 7 of Set 2 | mayo
# Processing Record 8 of Set 2 | bethel
# Processing Record 9 of Set 2 | soc trang
# Processing Record 10 of Set 2 | avarua
# Processing Record 11 of Set 2 | vieques
# Processing Record 12 of Set 2 | longyearbyen
# Processing Record 13 of Set 2 | sitka
# Processing Record 14 of Set 2 | nebug
# Processing Record 15 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 16 of Set 2 | port alfred
# Processing Record 17 of Set 2 
of Set 3 | amderma
# City not found. Skipping...
# Processing Record 43 of Set 3 | high level
# Processing Record 44 of Set 3 | hailar
# Processing Record 45 of Set 3 | amahai
# Processing Record 46 of Set 3 | miri
# Processing Record 47 of Set 3 | lompoc
# Processing Record 48 of Set 3 | ugoofaaru
# Processing Record 49 of Set 3 | muroto
# Processing Record 50 of Set 3 | paita
# Processing Record 1 of Set 4 | severo-kurilsk
# Processing Record 2 of Set 4 | kaduqli
# Processing Record 3 of Set 4 | port hedland
# Processing Record 4 of Set 4 | great yarmouth
# Processing Record 5 of Set 4 | luganville
# Processing Record 6 of Set 4 | anloga
# Processing Record 7 of Set 4 | starachowice
# Processing Record 8 of Set 4 | makakilo city
# Processing Record 9 of Set 4 | karaul
# City not found. Skipping...
# Processing Record 10 of Set 4 | constitucion
# Processing Record 11 of Set 4 | ishigaki
# Processing Record 12 of Set 4 | beltangadi
# Processing Record 13 of Set 4 | suntar
# Processing Record 14 of Set 4 | nanakuli
# Processing Record 15 of Set 4 | plouzane
# Processing Record 16 of Set 4 | usinsk
# Processing Record 17 of Set 4 | gat
# Processing Record 18 of Set 4 | kruisfontein
# Processing Record 19 of Set 4 | ribeira grande
# Processing Record 20 of Set 4 | brae
# Processing Record 21 of Set 4 | bredasdorp
# Processing Record 22 of Set 4 | lagoa
# Processing Record 23 of Set 4 | goderich
# Processing Record 24 of Set 4 | touros
# Processing Record 25 of Set 4 | yellowknife
# Processing Record 26 of Set 4 | vardo
# Processing Record 27 of Set 4 | palomares
# Processing Record 28 of Set 4 | yefira
# City not found. Skipping...
# Processing Record 29 of Set 4 | sobolevo
# Processing Record 30 of Set 4 | antalaha
# Processing Record 31 of Set 4 | khamanon
# Processing Record 32 of Set 4 | anamur
# Processing Record 33 of Set 4 | carora
# Processing Record 34 of Set 4 | klaksvik
# Processing Record 35 of Set 4 | kalaiya
# Processing Record 36 of Set 4 | nizhniy chir
# Processing Record 37 of Set 4 | punta alta
# Processing Record 38 of Set 4 | shache
# Processing Record 39 of Set 4 | kuche
# City not found. Skipping...
# Processing Record 40 of Set 4 | sulecin
# Processing Record 41 of Set 4 | thompson
# Processing Record 42 of Set 4 | oussouye
# Processing Record 43 of Set 4 | kahului
# Processing Record 44 of Set 4 | katsuura
# Processing Record 45 of Set 4 | melton
# Processing Record 46 of Set 4 | ziway
# Processing Record 47 of Set 4 | half moon bay
# Processing Record 48 of Set 4 | balikpapan
# Processing Record 49 of Set 4 | puerto colombia
# Processing Record 50 of Set 4 | rungata
# City not found. Skipping...
# Processing Record 1 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 2 of Set 5 | tocopilla
# Processing Record 3 of Set 5 | okha
# Processing Record 4 of Set 5 | san patricio
# Processing Record 5 of Set 5 | barrow
# Processing Record 6 of Set 5 | pascagoula
# Processing Record 7 of Set 5 | yaan
# Processing Record 8 of Set 5 | waddan
# Processing Record 9 of Set 5 | luderitz
# Processing Record 10 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 11 of Set 5 | jiroft
# City not found. Skipping...
# Processing Record 12 of Set 5 | port macquarie
# Processing Record 13 of Set 5 | kalabo
# Processing Record 14 of Set 5 | taolanaro
# City not found. Skipping...
# Processing Record 15 of Set 5 | jamestown
# Processing Record 16 of Set 5 | sarangani
# Processing Record 17 of Set 5 | sabang
# Processing Record 18 of Set 5 | hasaki
# Processing Record 19 of Set 5 | mahebourg
# Processing Record 20 of Set 5 | lodja
# Processing Record 21 of Set 5 | solwezi
# Processing Record 22 of Set 5 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 23 of Set 5 | kaitangata
# Processing Record 24 of Set 5 | chuy
# Processing Record 25 of Set 5 | saint-joseph
# Processing Record 26 of Set 5 | mahanoro
# Processing Record 27 of Set 5 | cockburn town
# Processing Record 28 of Set 5 | vostok
# Processing Record 29 of Set 5 | ambodifototra
# City not found. Skipping...
# Processing Record 30 of Set 5 | cayenne
# Processing Record 31 of Set 5 | hihifo
# City not found. Skipping...
# Processing Record 32 of Set 5 | husavik
# Processing Record 33 of Set 5 | umea
# Processing Record 34 of Set 5 | requena
# Processing Record 35 of Set 5 | chalmette
# Processing Record 36 of Set 5 | komsomolskiy
# Processing Record 37 of Set 5 | itarema
# Processing Record 38 of Set 5 | sao sebastiao do cai
# Processing Record 39 of Set 5 | wampusirpi
# City not found. Skipping...
# Processing Record 40 of Set 5 | torbay
# Processing Record 41 of Set 5 | liverpool
# Processing Record 42 of Set 5 | chabahar
# Processing Record 43 of Set 5 | greenwood
# Processing Record 44 of Set 5 | sacramento
# Processing Record 45 of Set 5 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 46 of Set 5 | salekhard
# Processing Record 47 of Set 5 | pasni
# Processing Record 48 of Set 5 | la ronge
# Processing Record 49 of Set 5 | todos santos
# Processing Record 50 of Set 5 | bam
# Processing Record 1 of Set 6 | manaia
# Processing Record 2 of Set 6 | padang
# Processing Record 3 of Set 6 | huanren
# Processing Record 4 of Set 6 | turukhansk
# Processing Record 5 of Set 6 | saint anthony
# Processing Record 6 of Set 6 | virginia beach
# Processing Record 7 of Set 6 | stawell
# Processing Record 8 of Set 6 | fortuna
# Processing Record 9 of Set 6 | westport
# Processing Record 10 of Set 6 | wahran
# City not found. Skipping...
# Processing Record 11 of Set 6 | allingabro
# Processing Record 12 of Set 6 | allahganj
# Processing Record 13 of Set 6 | iqaluit
# Processing Record 14 of Set 6 | berlevag
# Processing Record 15 of Set 6 | barguzin
# Processing Record 16 of Set 6 | kefamenanu
# Processing Record 17 of Set 6 | sao gabriel da cachoeira
# Processing Record 18 of Set 6 | uchiza
# Processing Record 19 of Set 6 | demyanovo
# Processing Record 20 of Set 6 | kulu
# Processing Record 21 of Set 6 | batticaloa
# Processing Record 22 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 23 of Set 6 | san quintin
# Processing Record 24 of Set 6 | novoagansk
# Processing Record 25 of Set 6 | kavieng
# Processing Record 26 of Set 6 | rafraf
# Processing Record 27 of Set 6 | camacupa
# Processing Record 28 of Set 6 | mount isa
# Processing Record 29 of Set 6 | boa vista
# Processing Record 30 of Set 6 | ust-kuyga
# Processing Record 31 of Set 6 | yumen
# Processing Record 32 of Set 6 | tighina
# Processing Record 33 of Set 6 | bengkulu
# Processing Record 34 of Set 6 | jiran
# Processing Record 35 of Set 6 | chokurdakh
# Processing Record 36 of Set 6 | poshekhonye
# Processing Record 37 of Set 6 | grand gaube
# Processing Record 38 of Set 6 | srandakan
# Processing Record 39 of Set 6 | reinosa
# Processing Record 40 of Set 6 | latung
# Processing Record 41 of Set 6 | flinders
# Processing Record 42 of Set 6 | nola
# Processing Record 43 of Set 6 | betsiamites
# Processing Record 44 of Set 6 | terney
# Processing Record 45 of Set 6 | kodiak
# Processing Record 46 of Set 6 | maumere
# Processing Record 47 of Set 6 | ahipara
# Processing Record 48 of Set 6 | brigantine
# Processing Record 49 of Set 6 | ca mau
# Processing Record 50 of Set 6 | doctor arroyo
# Processing Record 1 of Set 7 | bollnas
# Processing Record 2 of Set 7 | ilulissat
# Processing Record 3 of Set 7 | santa isabel
# Processing Record 4 of Set 7 | oktyabrskiy
# Processing Record 5 of Set 7 | tsaratanana
# Processing Record 6 of Set 7 | yerbogachen
# Processing Record 7 of Set 7 | cherskiy
# Processing Record 8 of Set 7 | hambantota
# Processing Record 9 of Set 7 | ankang
# Processing Record 10 of Set 7 | chumikan
# Processing Record 11 of Set 7 | mombaca
# Processing Record 12 of Set 7 | tsuyama
# Processing Record 13 of Set 7 | aberfeldy
# Processing Record 14 of Set 7 | maluko
# Processing Record 15 of Set 7 | sainte-marie
# Processing Record 16 of Set 7 | middle island
# Processing Record 17 of Set 7 | kolomna
# Processing Record 18 of Set 7 | san andres
# Processing Record 19 of Set 7 | quatre cocos
# Processing Record 20 of Set 7 | launceston
# Processing Record 21 of Set 7 | mayor pablo lagerenza
# Processing Record 22 of Set 7 | port hardy
# Processing Record 23 of Set 7 | leningradskiy
# Processing Record 24 of Set 7 | ossora
# Processing Record 25 of Set 7 | agirish
# Processing Record 26 of Set 7 | iskateley
# Processing Record 27 of Set 7 | belfort
# Processing Record 28 of Set 7 | sri aman
# Processing Record 29 of Set 7 | umarkot
# Processing Record 30 of Set 7 | healesville
# Processing Record 31 of Set 7 | meulaboh
# Processing Record 32 of Set 7 | arroio dos ratos
# Processing Record 33 of Set 7 | linxia
# Processing Record 34 of Set 7 | muisne
# Processing Record 35 of Set 7 | garowe
# Processing Record 36 of Set 7 | cabo san lucas
# Processing Record 37 of Set 7 | gaspe
# Processing Record 38 of Set 7 | whitehorse
# Processing Record 39 of Set 7 | abiy adi
# City not found. Skipping...
# Processing Record 40 of Set 7 | kindu
# Processing Record 41 of Set 7 | zonguldak
# Processing Record 42 of Set 7 | zhuozhou
# City not found. Skipping...
# Processing Record 43 of Set 7 | maralal
# Processing Record 44 of Set 7 | manchar
# Processing Record 45 of Set 7 | san felipe
# Processing Record 46 of Set 7 | sipe sipe
# Processing Record 47 of Set 7 | huilong
# Processing Record 48 of Set 7 | bayanday
# Processing Record 49 of Set 7 | aflu
# City not found. Skipping...
# Processing Record 50 of Set 7 | koutiala
# Processing Record 1 of Set 8 | semnan
# Processing Record 2 of Set 8 | krasnoye
# Processing Record 3 of Set 8 | gao
# Processing Record 4 of Set 8 | oktyabrskoye
# Processing Record 5 of Set 8 | cajnice
# Processing Record 6 of Set 8 | pochutla
# Processing Record 7 of Set 8 | kerouane
# Processing Record 8 of Set 8 | manutuke
# Processing Record 9 of Set 8 | tiruppur
# Processing Record 10 of Set 8 | talnakh
# Processing Record 11 of Set 8 | dharchula
# Processing Record 12 of Set 8 | te anau
# Processing Record 13 of Set 8 | abu kamal
# Processing Record 14 of Set 8 | guerrero negro
# Processing Record 15 of Set 8 | matara
# Processing Record 16 of Set 8 | hamilton
# Processing Record 17 of Set 8 | lazaro cardenas
# Processing Record 18 of Set 8 | olga
# Processing Record 19 of Set 8 | yuxia
# Processing Record 20 of Set 8 | margate
# Processing Record 21 of Set 8 | mombetsu
# Processing Record 22 of Set 8 | bambous virieux
# Processing Record 23 of Set 8 | pangnirtung
# Processing Record 24 of Set 8 | bathsheba
# Processing Record 25 of Set 8 | burgthann
# Processing Record 26 of Set 8 | grand centre
# City not found. Skipping...
# Processing Record 27 of Set
# Processing Record 45 of Set 9 | mersing
# Processing Record 46 of Set 9 | talcahuano
# Processing Record 47 of Set 9 | kikwit
# Processing Record 48 of Set 9 | moa
# Processing Record 49 of Set 9 | esil
# Processing Record 50 of Set 9 | doha
# Processing Record 1 of Set 10 | kytlym
# City not found. Skipping...
# Processing Record 2 of Set 10 | vila franca do campo
# Processing Record 3 of Set 10 | ingham
# Processing Record 4 of Set 10 | yar-sale
# Processing Record 5 of Set 10 | dinghai
# Processing Record 6 of Set 10 | batemans bay
# Processing Record 7 of Set 10 | kuito
# Processing Record 8 of Set 10 | pokaran
# Processing Record 9 of Set 10 | milkovo
# Processing Record 10 of Set 10 | gigmoto
# Processing Record 11 of Set 10 | pauini
# Processing Record 12 of Set 10 | poplar bluff
# Processing Record 13 of Set 10 | manoel urbano
# Processing Record 14 of Set 10 | sinnamary
# Processing Record 15 of Set 10 | leixlip
# Processing Record 16 of Set 10 | broken hill
# Processing Record 17 of Set 10 | marshfield
# Processing Record 18 of Set 10 | yazykovo
# Processing Record 19 of Set 10 | codrington
# Processing Record 20 of Set 10 | tessalit
# Processing Record 21 of Set 10 | ambilobe
# Processing Record 22 of Set 10 | leshukonskoye
# Processing Record 23 of Set 10 | champerico
# Processing Record 24 of Set 10 | kichera
# Processing Record 25 of Set 10 | katherine
# Processing Record 26 of Set 10 | yenagoa
# Processing Record 27 of Set 10 | gemena
# Processing Record 28 of Set 10 | revelstoke
# Processing Record 29 of Set 10 | salalah
# Processing Record 30 of Set 10 | tual
# Processing Record 31 of Set 10 | upernavik
# Processing Record 32 of Set 10 | srednekolymsk
# Processing Record 33 of Set 10 | uni
# Processing Record 34 of Set 10 | beringovskiy
# Processing Record 35 of Set 10 | lorengau
# Processing Record 36 of Set 10 | kulhudhuffushi
# Processing Record 37 of Set 10 | lanivtsi
# Processing Record 38 of Set 10 | oleksandrivka
# Processing Record 39 of Set 10 | lavrentiya
# Processing Record 40 of Set 10 | yurimaguas
# Processing Record 41 of Set 10 | lowestoft
# Processing Record 42 of Set 10 | samarai
# Processing Record 43 of Set 10 | deputatskiy
# Processing Record 44 of Set 10 | chapais
# Processing Record 45 of Set 10 | faanui
# Processing Record 46 of Set 10 | narsaq
# Processing Record 47 of Set 10 | pointe michel
# Processing Record 48 of Set 10 | yelizovo
# Processing Record 49 of Set 10 | urengoy
# Processing Record 50 of Set 10 | mancio lima
# Processing Record 1 of Set 11 | khandyga
# Processing Record 2 of Set 11 | labuhan
# Processing Record 3 of Set 11 | almaznyy
# Processing Record 4 of Set 11 | camalu
# Processing Record 5 of Set 11 | vagay
# Processing Record 6 of Set 11 | sampit
# Processing Record 7 of Set 11 | ixtapa
# Processing Record 8 of Set 11 | asyut
# Processing Record 9 of Set 11 | khonuu
# City not found. Skipping...
# Processing Record 10 of Set 11 | nuuk
# Processing Record 11 of Set 11 | phangnga
# Processing Record 12 of Set 11 | ornskoldsvik
# Processing Record 13 of Set 11 | misratah
# Processing Record 14 of Set 11 | barbar
# City not found. Skipping...
# Processing Record 15 of Set 11 | zhangjiakou
# Processing Record 16 of Set 11 | polunochnoye
# Processing Record 17 of Set 11 | coihaique
# Processing Record 18 of Set 11 | cam ranh
# Processing Record 19 of Set 11 | hokitika
# Processing Record 20 of Set 11 | mayumba
# Processing Record 21 of Set 11 | baruun-urt
# Processing Record 22 of Set 11 | vagur
# Processing Record 23 of Set 11 | manuk mangkaw
# Processing Record 24 of Set 11 | wajid
# Processing Record 25 of Set 11 | sandpoint
# Processing Record 26 of Set 11 | tucumcari
# Processing Record 27 of Set 11 | haapiti
# Processing Record 28 of Set 11 | saint-georges
# Processing Record 29 of Set 11 | karauzyak
# City not found. Skipping...
# Processing Record 30 of Set 11 | saldanha
# Processing Record 31 of Set 11 | warqla
# City not found. Skipping...
# Processing Record 32 of Set 11 | ostrovnoy
# Processing Record 33 of Set 11 | kloulklubed
# Processing Record 34 of Set 11 | santa maria
# Processing Record 35 of Set 11 | pontal do parana
# Processing Record 36 of Set 11 | baykit
# Processing Record 37 of Set 11 | saint-michel-des-saints
# Processing Record 38 of Set 11 | san juan de los lagos
# Processing Record 39 of Set 11 | livingston
# Processing Record 40 of Set 11 | magadi
# Processing Record 41 of Set 11 | valparaiso
# Processing Record 42 of Set 11 | xam nua
# Processing Record 43 of Set 11 | jiaonan
# Processing Record 44 of Set 11 | luis moya
# Processing Record 45 of Set 11 | mbacke
# City not found. Skipping...
# Processing Record 46 of Set 11 | qaqortoq
# Processing Record 47 of Set 11 | tomohon
# Processing Record 48 of Set 11 | etchoropo
# Processing Record 49 of Set 11 | vanavara
# Processing Record 50 of Set 11 | angoche
# Processing Record 1 of Set 12 | nsanje
# Processing Record 2 of Set 12 | saint george
# Processing Record 3 of Set 12 | los llanos de aridane
# Processing Record 4 of Set 12 | riachao do jacuipe
# Processing Record 5 of Set 12 | nantucket
# Processing Record 6 of Set 12 | hobyo
# Processing Record 7 of Set 12 | kalamare
# Processing Record 8 of Set 12 | cape coast
# Processing Record 9 of Set 12 | aklavik
# Processing Record 10 of Set 12 | sisimiut
# Processing Record 11 of Set 12 | tuatapere
# Processing Record 12 of Set 12 | vila velha
# Processing Record 13 of Set 12 | urusha
# Processing Record 14 of Set 12 | saint-pierre
# Processing Record 15 of Set 12 | gizo
# Processing Record 16 of Set 12 | shelburne
# Processing Record 17 of Set 12 | iraray
# Processing Record 18 of Set 12 | lolua
# City not found. Skipping...
# Processing Record 19 of Set 12 | amapa
# Processing Record 20 of Set 12 | pisco
# Processing Record 21 of Set 12 | ksenyevka
# City not found. Skipping...
# Processing Record 22 of Set 12 | angra
# City not found. Skipping...
# Processing Record 23 of Set 12 | el dorado
# Processing Record 24 of Set 12 | kangaatsiaq
# Processing Record 25 of Set 12 | palabuhanratu
# City not found. Skipping...
# Processing Record 26 of Set 12 | korla
# Processing Record 27 of Set 12 | koboldo
# City not found. Skipping...
# Processing Record 28 of Set 12 | caxias
# Processing Record 29 of Set 12 | aguai
# Processing Record 30 of Set 12 | juybar
# Processing Record 31 of Set 12 | cairns
# Processing Record 32 of Set 12 | palmer
# Processing Record 33 of Set 12 | uhlove
# Processing Record 34 of Set 12 | staromaryevka
# City not found. Skipping...
# Processing Record 35 of Set 12 | gornopravdinsk
# Processing Record 36 of Set 12 | magistralnyy
# Processing Record 37 of Set 12 | yagodnoye
# Processing Record 38 of Set 12 | hofn
# Processing Record 39 of Set 12 | tobol
# Processing Record 40 of Set 12 | lasa
# Processing Record 41 of Set 12 | emmett
# Processing Record 42 of Set 12 | ocos
# Processing Record 43 of Set 12 | aranos
# Processing Record 44 of Set 12 | mirnyy
# Processing Record 45 of Set 12 | biak
# Processing Record 46 of Set 12 | akureyri
# Processing Record 47 of Set 12 | pringsewu
# Processing Record 48 of Set 12 | tilichiki
# Processing Record 49 of Set 12 | likhoy
# Processing Record 50 of Set 12 | vanimo
# Processing Record 1 of Set 13 | tabiauea
# City not found. Skipping...
# Processing Record 2 of Set 13 | sao filipe
# Processing Record 3 of Set 13 | poum
# Processing Record 4 of Set 13 | zyryanka
# Processing Record 5 of Set 13 | otane
# Processing Record 6 of Set 13 | lexington
# Processing Record 7 of Set 13 | shingu
# Processing Record 8 of Set 13 | mitzic
# Processing Record 9 of Set 13 | ban nahin
# Processing Record 10 of Set 13 | alpena
# Processing Record 11 of Set 13 | severo-yeniseyskiy
# Processing Record 12 of Set 13 | aktas
# Processing Record 13 of Set 13 | waingapu
# Processing Record 14 of Set 13 | elizabeth city
# Processing Record 15 of Set 13 | aden
# Processing Record 16 of Set 13 | stornoway
# Processing Record 17 of Set 13 | bara
# Processing Record 18 of Set 13 | kavaratti
# Processing Record 19 of Set 13 | olafsvik
# Processing Record 20 of Set 13 | ferkessedougou
# Processing Record 21 of Set 13 | kerki
# City not found. Skipping...
# Processing Record 22 of Set 13 | marcona
# City not found. Skipping...
# Data Retrieval Complete

# %%
len(lat)
# Out:
# 622

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# convert raw data to dataframe
city_weather_df = pd.DataFrame({
    "City": cities,
    "Lat": lat,
    "Lng": lon,
    "Max Temp": temp_max,
    "Humidity": humidity,
    "Cloudiness": cloudiness,
    "Wind Speed": wind_speed,
    "Country": country,
    "Date": date,
})

# drop cities that were skipped because they could not be found by the api
city_weather_df = city_weather_df.dropna(how="any")

# %%
# export the city data into a .csv file within a folder named output_data
city_weather_df.to_csv("./output_data/city_weather_data.csv", index=False)

# display the dataframe
city_weather_df
# Out:
#                City    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0            castro -24.79  -50.01     79.16      52.0        50.0
# 1          maragogi  -9.01  -35.22     81.86      63.0        25.0
# 2            marzuq  14.40   46.47     77.95      17.0        14.0
# 3            dikson  73.51   80.55     21.61      95.0        91.0
# 4        georgetown   5.41  100.34     84.20      83.0        20.0
# ..              ...    ...     ...       ...       ...         ...
# 615       stornoway  58.21   -6.39     51.80      93.0        75.0
# 616            bara  10.37   10.73     93.20      32.0        20.0
# 617       kavaratti  10.57   72.64     81.81      72.0       100.0
# 618        olafsvik  64.89  -23.71     36.88      91.0       100.0
# 619  ferkessedougou   9.60   -5.20     89.33      52.0        36.0
#
#      Wind Speed Country          Date
# 0          3.20      BR  1.603206e+09
# 1         10.71      BR  1.603206e+09
# 2          9.04      YE  1.603207e+09
# 3         10.29      RU  1.603206e+09
# 4          3.36      MY  1.603206e+09
# ..          ...     ...           ...
# 615       18.34      GB  1.603206e+09
# 616       11.41      NG  1.603207e+09
# 617       10.11      IN  1.603207e+09
# 618       10.92      IS  1.603206e+09
# 619        3.65      CI  1.603207e+09
#
# [569 rows x 9 columns]

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#  Get the indices of cities that have humidity over 100%.

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression
